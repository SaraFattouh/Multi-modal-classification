# %% [markdown]
# # Multimodal Calssification on Rakuten France Dataset
# # Multi Modal Addition Fusion

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
# mv './image_1/image' '../image'

# %%
# mv image Rakuten

# %%
mkdir Rakuten

# %%
cd './Rakuten'
# Out:
# /content/Rakuten

# %%
mkdir models data

# %%
pwd
# Out:
# '/content/Rakuten'

# %%
ls -la
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 May  9 23:18 ./
# drwxr-xr-x 1 root root 4096 May  9 23:18 ../
# drwxr-xr-x 2 root root 4096 May  9 23:18 data/
# drwxr-xr-x 2 root root 4096 May  9 23:18 models/

# %%
cp '/content/drive/My Drive/Rakuten/models/CamemBERT_best_model_baseline.pt' models

# %%
cp '/content/drive/My Drive/Rakuten/models/FlauBERT_best_model_baseline.pt' models

# %%
cp '/content/drive/My Drive/Rakuten/models/RESNET_baseline_model.pt' models

# %%
# !cp  '/content/drive/My Drive/Rakuten/image.zip' './'

# %%
# !unzip  ./image.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: image/image_training/image_941622041_product_207151319.jpg
#   inflating: image/image_training/image_941622046_product_207151571.jpg
#   inflating: image/image_training/image_941622048_product_207151338.jpg
#   inflating: image/image_training/image_941622055_product_207151480.jpg
#   inflating: image/image_training/image_941622057_product_207151296.jpg
#   inflating: image/image_training/image_941622063_product_207151539.jpg
#   inflating: image/image_training/image_941622065_product_207151527.jpg
#   inflating: image/image_training/image_941622067_product_207151563.jpg
#   inflating: image/image_training/image_941622071_product_207151331.jpg
#   inflating: image/image_training/image_941622073_product_207151492.jpg
#   inflating: image/image_training/image_941622084_product_207151508.jpg
#   inflating: image/image_training/image_941622086_product_207151543.jpg
#   inflating: image/image_training/image_941622094_product_207151287.jpg
#   inflating: image/image_training/image_941622096_product_207151567.jpg
#   inflating: image/image_training/image_941622100_product_207151555.jpg
#   inflating: image/image_training/image_941622102_product_207151329.jpg
#   inflating: image/image_training/image_941622104_product_207151308.jpg
#   inflating: image/image_training/image_941622113_product_207151291.jpg
#   inflating: image/image_training/image_941622124_product_207151478.jpg
#   inflating: image/image_training/image_941622130_product_207151336.jpg
#   inflating: image/image_training/image_941622136_product_207151475.jpg
#   inflating: image/image_training/image_941622138_product_207151518.jpg
#   inflating: image/image_training/image_941622142_product_207151314.jpg
#   inflating: image/image_training/image_941622146_product_207151281.jpg
#   inflating: image/image_training/image_941622148_product_207151295.jpg
#   inflating: image/image_training/image_941622150_product_207151503.jpg
#   inflating: image/image_training/image_941622152_product_207151461.jpg
#   inflating: image/image_training/image_941622154_product_207151335.jpg
#   inflating: image/image_training/image_941622156_product_207151477.jpg
#   inflating: image/image_training/image_941622170_product_207151491.jpg
#   inflating: image/image_training/image_941622174_product_207151570.jpg
#   inflating: image/image_training/image_941622181_product_207151297.jpg
#   inflating: image/image_training/image_941622183_product_207151573.jpg
#   inflating: image/image_training/image_941622187_product_207151529.jpg
#   inflating: image/image_training/image_941622193_product_207151283.jpg
#   inflating: image/image_training/image_941622195_product_207151506.jpg
#   inflating: image/image_training/image_941622197_product_207151572.jpg
#   inflating: image/image_training/image_941622199_product_207151317.jpg
#   inflating: image/image_training/image_941622203_product_207151465.jpg
#   inflating: image/image_training/image_941622208_product_207151541.jpg
#   inflating: image/image_training/image_941622213_product_207151504.jpg
#   inflating: image/image_training/image_941622215_product_207151299.jpg
#   inflating: image/image_training/image_941622217_product_207151494.jpg
#   inflating: image/image_training/image_941622220_product_207151322.jpg
#   inflating: image/image_training/image_941622222_product_207151489.jpg
#   inflating: image/image_training/image_941622232_product_207151528.jpg
#   inflating: image/image_training/image_941622236_product_207151507.jpg
#   inflating: image/image_training/image_941622238_product_207151309.jpg
#   inflating: image/image_training/image_941622248_product_207151515.jpg
#   inflating: image/image_training/image_941622252_product_207151530.jpg
#   inflating: image/image_training/image_941622258_product_207151544.jpg
#   inflating: image/image_training/image_941622263_product_207151290.jpg
#   inflating: image/image_training/image_941622269_product_207151481.jpg
#   inflating: image/image_training/image_941622272_product_207151553.jpg
#   inflating: image/image_training/image_941622274_product_207151289.jpg
#   inflating: image/image_training/image_941622279_product_207151536.jpg
#   inflating: image/image_training/image_941622281_product_207151551.jpg
#   inflating: image/image_training/image_941632465_product_207159785.jpg
#   inflating: image/image_training/image_941634929_product_207159776.jpg
#   inflating: image/image_training/image_941635457_product_207159381.jpg
#   inflating: image/image_training/image_941642508_product_207170094.jpg
#   inflating: image/image_training/image_941642512_product_207170102.jpg
#   inflating: image/image_training/image_941642515_product_207170091.jpg
#   inflating: image/image_training/image_941642522_product_207170105.jpg
#   inflating: image/image_training/image_941642524_product_207170097.jpg
#   inflating: image/image_training/image_941643039_product_207170092.jpg
#   inflating: image/image_training/image_941643041_product_207170095.jpg
#   inflating: image/image_training/image_941643043_product_207170098.jpg
#   inflating: image/image_training/image_941643048_product_207170089.jpg
#   inflating: image/image_training/image_941643065_product_207170090.jpg
#   inflating: image/image_training/image_941653250_product_207208979.jpg
#   inflating: image/image_training/image_941657086_product_207008677.jpg
#   inflating: image/image_training/image_941657121_product_207119770.jpg
#   inflating: image/image_training/image_941658827_product_206671196.jpg
#   inflating: image/image_training/image_941666614_product_207129086.jpg
#   inflating: image/image_training/image_941672860_product_207072607.jpg
#   inflating: image/image_training/image_941676206_product_207258056.jpg
#   inflating: image/image_training/image_941676210_product_207257918.jpg
#   inflating: image/image_training/image_941676214_product_207258066.jpg
#   inflating: image/image_training/image_941676216_product_207257878.jpg
#   inflating: image/image_training/image_941676640_product_207257949.jpg
#   inflating: image/image_training/image_941676652_product_207257880.jpg
#   inflating: image/image_training/image_941676654_product_207257877.jpg
#   inflating: image/image_training/image_941676660_product_207257895.jpg
#   inflating: image/image_training/image_941676662_product_207258080.jpg
#   inflating: image/image_training/image_941676676_product_207196204.jpg
#   inflating: image/image_training/image_941676692_product_207257936.jpg
#   inflating: image/image_training/image_941676702_product_207196245.jpg
#   inflating: image/image_training/image_941676704_product_207258055.jpg
#   inflating: image/image_training/image_941676712_product_207258062.jpg
#   inflating: image/image_training/image_941677134_product_207257922.jpg
#   inflating: image/image_training/image_941677136_product_207196227.jpg
#   inflating: image/image_training/image_941677140_product_207257921.jpg
#   inflating: image/image_training/image_941677144_product_207196182.jpg
#   inflating: image/image_training/image_941677156_product_207257892.jpg
#   inflating: image/image_training/image_941677170_product_207196206.jpg
#   inflating: image/image_training/image_941677178_product_207258159.jpg
#   inflating: image/image_training/image_941677998_product_207196178.jpg
#   inflating: image/image_training/image_941678002_product_207196180.jpg
#   inflating: image/image_training/image_941678009_product_207196192.jpg
#   inflating: image/image_training/image_941678014_product_207257914.jpg
#   inflating: image/image_training/image_941678016_product_207196196.jpg
#   inflating: image/image_training/image_941678018_product_207257905.jpg
#   inflating: image/image_training/image_941678309_product_207196248.jpg
#   inflating: image/image_training/image_941678319_product_207257891.jpg
#   inflating: image/image_training/image_941678322_product_207257916.jpg
#   inflating: image/image_training/image_941678324_product_207196229.jpg
#   inflating: image/image_training/image_941678337_product_207196201.jpg
#   inflating: image/image_training/image_941678351_product_207258158.jpg
#   inflating: image/image_training/image_941678361_product_207257911.jpg
#   inflating: image/image_training/image_941678375_product_207257886.jpg
#   inflating: image/image_training/image_941678382_product_207196239.jpg
#   inflating: image/image_training/image_941678386_product_207258199.jpg
#   inflating: image/image_training/image_941678397_product_207258060.jpg
#   inflating: image/image_training/image_941678411_product_207257917.jpg
#   inflating: image/image_training/image_941678415_product_207258161.jpg
#   inflating: image/image_training/image_941678422_product_207196235.jpg
#   inflating: image/image_training/image_941678447_product_207258117.jpg
#   inflating: image/image_training/image_941678458_product_207196199.jpg
#   inflating: image/image_training/image_941678462_product_207258050.jpg
#   inflating: image/image_training/image_941678490_product_207257894.jpg
#   inflating: image/image_training/image_941678534_product_207258064.jpg
#   inflating: image/image_training/image_941678536_product_207196230.jpg
#   inflating: image/image_training/image_941678540_product_207258156.jpg
#   inflating: image/image_training/image_941678546_product_207257909.jpg
#   inflating: image/image_training/image_941678550_product_207258063.jpg
#   inflating: image/image_training/image_941678552_product_207257912.jpg
#   inflating: image/image_training/image_941678554_product_207257881.jpg
#   inflating: image/image_training/image_941678558_product_207196205.jpg
#   inflating: image/image_training/image_941678560_product_207258162.jpg
#   inflating: image/image_training/image_941678562_product_207258079.jpg
#   inflating: image/image_training/image_941678582_product_207196218.jpg
#   inflating: image/image_training/image_941678588_product_207257898.jpg
#   inflating: image/image_training/image_941678590_product_207258051.jpg
#   inflating: image/image_training/image_941678600_product_207258102.jpg
#   inflating: image/image_training/image_941678606_product_207257896.jpg
#   inflating: image/image_training/image_941678615_product_207257910.jpg
#   inflating: image/image_training/image_941678626_product_207196162.jpg
#   inflating: image/image_training/image_941678631_product_207257943.jpg
#   inflating: image/image_training/image_941678641_product_207196247.jpg
#   inflating: image/image_training/image_941678666_product_207257920.jpg
#   inflating: image/image_training/image_941678684_product_207196225.jpg
#   inflating: image/image_training/image_941678688_product_207257889.jpg
#   inflating: image/image_training/image_941678692_product_207257930.jpg
#   inflating: image/image_training/image_941678701_product_207258057.jpg
#   inflating: image/image_training/image_941678711_product_207258154.jpg
#   inflating: image/image_training/image_941678713_product_207196194.jpg
#   inflating: image/image_training/image_941678715_product_207196193.jpg
#   inflating: image/image_training/image_941678719_product_207196198.jpg
#   inflating: image/image_training/image_941678721_product_207257897.jpg
#   inflating: image/image_training/image_941678723_product_207257919.jpg
#   inflating: image/image_training/image_941678727_product_207257948.jpg
#   inflating: image/image_training/image_941678734_product_207258067.jpg
#   inflating: image/image_training/image_941678738_product_207257913.jpg
#   inflating: image/image_training/image_941678740_product_207196195.jpg
#   inflating: image/image_training/image_941678742_product_207196200.jpg
#   inflating: image/image_training/image_941678744_product_207257883.jpg
#   inflating: image/image_training/image_941678756_product_207258103.jpg
#   inflating: image/image_training/image_941678758_product_207196181.jpg
#   inflating: image/image_training/image_941678760_product_207196226.jpg
#   inflating: image/image_training/image_941678768_product_207196190.jpg
#   inflating: image/image_training/image_941678776_product_207258087.jpg
#   inflating: image/image_training/image_941678778_product_207196231.jpg
#   inflating: image/image_training/image_941678782_product_207257907.jpg
#   inflating: image/image_training/image_941678793_product_207196224.jpg
#   inflating: image/image_training/image_941678799_product_207258150.jpg
#   inflating: image/image_training/image_941678801_product_207196179.jpg
#   inflating: image/image_training/image_941678807_product_207258061.jpg
#   inflating: image/image_training/image_941678818_product_207257887.jpg
#   inflating: image/image_training/image_941678848_product_207257923.jpg
#   inflating: image/image_training/image_941678850_product_207257906.jpg
#   inflating: image/image_training/image_941678852_product_207258076.jpg
#   inflating: image/image_training/image_941678856_product_207257904.jpg
#   inflating: image/image_training/image_941678870_product_207257942.jpg
#   inflating: image/image_training/image_941678887_product_207258101.jpg
#   inflating: image/image_training/image_941678889_product_207258059.jpg
#   inflating: image/image_training/image_941678895_product_207257899.jpg
#   inflating: image/image_training/image_941678907_product_207258168.jpg
#   inflating: image/image_training/image_941678909_product_207257935.jpg
#   inflating: image/image_training/image_941678925_product_207257938.jpg
#   inflating: image/image_training/image_941678927_product_207258052.jpg
#   inflating: image/image_training/image_941679033_product_207258065.jpg
#   inflating: image/image_training/image_941680860_product_201700578.jpg
#   inflating: image/image_training/image_941693567_product_207287172.jpg
#   inflating: image/image_training/image_941693581_product_207287166.jpg
#   inflating: image/image_training/image_941693586_product_207287179.jpg
#   inflating: image/image_training/image_941693588_product_207287176.jpg
#   inflating: image/image_training/image_941693594_product_207287178.jpg
#   inflating: image/image_training/image_941693596_product_207287181.jpg
#   inflating: image/image_training/image_941693603_product_207287191.jpg
#   inflating: image/image_training/image_941693605_product_207287183.jpg
#   inflating: image/image_training/image_941693634_product_207287177.jpg
#   inflating: image/image_training/image_941693644_product_207287175.jpg
#   inflating: image/image_training/image_941693648_product_207287170.jpg
#   inflating: image/image_training/image_941693650_product_207287188.jpg
#   inflating: image/image_training/image_941693658_product_207287189.jpg
#   inflating: image/image_training/image_941693674_product_207287174.jpg
#   inflating: image/image_training/image_941693676_product_207287171.jpg
#   inflating: image/image_training/image_941693678_product_207287169.jpg
#   inflating: image/image_training/image_941693682_product_207287196.jpg
#   inflating: image/image_training/image_941693684_product_207287165.jpg
#   inflating: image/image_training/image_941693686_product_207287184.jpg
#   inflating: image/image_training/image_941693688_product_207287173.jpg
#   inflating: image/image_training/image_941693689_product_207286233.jpg
#   inflating: image/image_training/image_941693695_product_207287182.jpg
#   inflating: image/image_training/image_941693697_product_207287190.jpg
#   inflating: image/image_training/image_941693699_product_207287187.jpg
#   inflating: image/image_training/image_941696681_product_207288971.jpg
#   inflating: image/image_training/image_941697515_product_207289359.jpg
#   inflating: image/image_training/image_941698026_product_207289304.jpg
#   inflating: image/image_training/image_941702968_product_207292686.jpg
#   inflating: image/image_training/image_941709913_product_207304894.jpg
#   inflating: image/image_training/image_941710141_product_5064576.jpg
#   inflating: image/image_training/image_941710215_product_207304671.jpg
#   inflating: image/image_training/image_941710306_product_207304864.jpg
#   inflating: image/image_training/image_941710580_product_190099239.jpg
#   inflating: image/image_training/image_941710645_product_207304977.jpg
#   inflating: image/image_training/image_941710864_product_80378291.jpg
#   inflating: image/image_training/image_941710868_product_207304902.jpg
#   inflating: image/image_training/image_941719274_product_207310349.jpg
#   inflating: image/image_training/image_941721653_product_48598697.jpg
#   inflating: image/image_training/image_941749808_product_207249756.jpg
#   inflating: image/image_training/image_941749826_product_207249762.jpg
#   inflating: image/image_training/image_941752952_product_207249771.jpg
#   inflating: image/image_training/image_941755156_product_207263631.jpg
#   inflating: image/image_training/image_941760727_product_207114514.jpg
#   inflating: image/image_training/image_941766532_product_207404801.jpg
#   inflating: image/image_training/image_941801254_product_207481762.jpg
#   inflating: image/image_training/image_941839136_product_207542568.jpg
#   inflating: image/image_training/image_941855135_product_207163830.jpg
#   inflating: image/image_training/image_941870372_product_207132325.jpg
#   inflating: image/image_training/image_941872757_product_174843392.jpg
#   inflating: image/image_training/image_941874086_product_207639272.jpg
#   inflating: image/image_training/image_941874094_product_207639280.jpg
#   inflating: image/image_training/image_941874108_product_207639264.jpg
#   inflating: image/image_training/image_941883982_product_207543180.jpg
#   inflating: image/image_training/image_941883990_product_207555699.jpg
#   inflating: image/image_training/image_941884473_product_70060718.jpg
#   inflating: image/image_training/image_941884476_product_207548491.jpg
#   inflating: image/image_training/image_941885425_product_207632469.jpg
#   inflating: image/image_training/image_941885531_product_207626492.jpg
#   inflating: image/image_training/image_941902501_product_207703914.jpg
#   inflating: image/image_training/image_941906257_product_207704542.jpg
#   inflating: image/image_training/image_941993992_product_207785600.jpg
#   inflating: image/image_training/image_942027813_product_207914057.jpg
#   inflating: image/image_training/image_942033629_product_207962482.jpg
#   inflating: image/image_training/image_942034991_product_207977444.jpg
#   inflating: image/image_training/image_942063538_product_208026590.jpg
#   inflating: image/image_training/image_942069842_product_208038176.jpg
#   inflating: image/image_training/image_942083617_product_208082265.jpg
#   inflating: image/image_training/image_942085827_product_207489274.jpg
#   inflating: image/image_training/image_942086395_product_158982305.jpg
#   inflating: image/image_training/image_942087006_product_138732065.jpg
#   inflating: image/image_training/image_942099182_product_207680953.jpg
#   inflating: image/image_training/image_942210828_product_208194729.jpg
#   inflating: image/image_training/image_9456930_product_992281.jpg
#   inflating: image/image_training/image_946228894_product_3507566.jpg
#   inflating: image/image_training/image_946230965_product_207673978.jpg
#   inflating: image/image_training/image_946230975_product_207672178.jpg
#   inflating: image/image_training/image_946230990_product_207691159.jpg
#   inflating: image/image_training/image_946230992_product_207691173.jpg
#   inflating: image/image_training/image_946231005_product_207696723.jpg
#   inflating: image/image_training/image_946231149_product_208072197.jpg
#   inflating: image/image_training/image_946232026_product_185194885.jpg
#   inflating: image/image_training/image_946233952_product_208307868.jpg
#   inflating: image/image_training/image_946250445_product_208333647.jpg
#   inflating: image/image_training/image_946263224_product_49582852.jpg
#   inflating: image/image_training/image_946264883_product_53929449.jpg
#   inflating: image/image_training/image_946265426_product_55043513.jpg
#   inflating: image/image_training/image_946267926_product_57229958.jpg
#   inflating: image/image_training/image_946267956_product_56381004.jpg
#   inflating: image/image_training/image_946269034_product_56442955.jpg
#   inflating: image/image_training/image_946269195_product_57233146.jpg
#   inflating: image/image_training/image_946271032_product_57542403.jpg
#   inflating: image/image_training/image_946271075_product_208363010.jpg
#   inflating: image/image_training/image_946272484_product_57158581.jpg
#   inflating: image/image_training/image_946272855_product_59728602.jpg
#   inflating: image/image_training/image_946272865_product_59839586.jpg
#   inflating: image/image_training/image_946273069_product_16378945.jpg
#   inflating: image/image_training/image_946273142_product_60347031.jpg
#   inflating: image/image_training/image_946273165_product_208364111.jpg
#   inflating: image/image_training/image_946273252_product_60415950.jpg
#   inflating: image/image_training/image_946273520_product_88366751.jpg
#   inflating: image/image_training/image_946273912_product_62995885.jpg
#   inflating: image/image_training/image_946274320_product_96501221.jpg
#   inflating: image/image_training/image_946280133_product_75245524.jpg
#   inflating: image/image_training/image_946297679_product_92813202.jpg
#   inflating: image/image_training/image_946298451_product_77635459.jpg
#   inflating: image/image_training/image_946299004_product_71670136.jpg
#   inflating: image/image_training/image_946301932_product_208381222.jpg
#   inflating: image/image_training/image_946302448_product_208381920.jpg
#   inflating: image/image_training/image_946307097_product_208384576.jpg
#   inflating: image/image_training/image_946314613_product_208306711.jpg
#   inflating: image/image_training/image_946328775_product_63958052.jpg
#   inflating: image/image_training/image_946376404_product_207892663.jpg
#   inflating: image/image_training/image_946424001_product_196888225.jpg
#   inflating: image/image_training/image_946448511_product_208539341.jpg
#   inflating: image/image_training/image_946468414_product_85356803.jpg
#   inflating: image/image_training/image_946470989_product_205707244.jpg
#   inflating: image/image_training/image_946489233_product_205951947.jpg
#   inflating: image/image_training/image_946508640_product_205823670.jpg
#   inflating: image/image_training/image_946517531_product_179274912.jpg
#   inflating: image/image_training/image_946518577_product_196547987.jpg
#   inflating: image/image_training/image_946530575_product_203948672.jpg
#   inflating: image/image_training/image_946534904_product_191848447.jpg
#   inflating: image/image_training/image_946553062_product_199083268.jpg
#   inflating: image/image_training/image_946555389_product_148244303.jpg
#   inflating: image/image_training/image_946556640_product_205557086.jpg
#   inflating: image/image_training/image_946557204_product_205560139.jpg
#   inflating: image/image_training/image_946563724_product_180145096.jpg
#   inflating: image/image_training/image_946580688_product_204251288.jpg
#   inflating: image/image_training/image_946584131_product_206461609.jpg
#   inflating: image/image_training/image_946589879_product_208035660.jpg
#   inflating: image/image_training/image_946590676_product_208427217.jpg
#   inflating: image/image_training/image_946638314_product_208617401.jpg
#   inflating: image/image_training/image_946641178_product_189613830.jpg
#   inflating: image/image_training/image_946685896_product_192442770.jpg
#   inflating: image/image_training/image_946687253_product_161999894.jpg
#   inflating: image/image_training/image_946687617_product_143446374.jpg
#   inflating: image/image_training/image_946699126_product_208684132.jpg
#   inflating: image/image_training/image_946699128_product_208684131.jpg
#   inflating: image/image_training/image_946699871_product_208686943.jpg
#   inflating: image/image_training/image_946699877_product_208686946.jpg
#   inflating: image/image_training/image_946699880_product_208686945.jpg
#   inflating: image/image_training/image_946699881_product_208686942.jpg
#   inflating: image/image_training/image_946699882_product_208686939.jpg
#   inflating: image/image_training/image_946702481_product_208697564.jpg
#   inflating: image/image_training/image_946713999_product_208715308.jpg
#   inflating: image/image_training/image_946714000_product_208715288.jpg
#   inflating: image/image_training/image_946714001_product_208715297.jpg
#   inflating: image/image_training/image_946714002_product_208715285.jpg
#   inflating: image/image_training/image_946714003_product_208715282.jpg
#   inflating: image/image_training/image_946714005_product_208715310.jpg
#   inflating: image/image_training/image_946714006_product_208715296.jpg
#   inflating: image/image_training/image_946714008_product_208715283.jpg
#   inflating: image/image_training/image_946714009_product_208715304.jpg
#   inflating: image/image_training/image_946714013_product_208715293.jpg
#   inflating: image/image_training/image_946714015_product_208715292.jpg
#   inflating: image/image_training/image_946714019_product_208715311.jpg
#   inflating: image/image_training/image_946714020_product_208715300.jpg
#   inflating: image/image_training/image_946714022_product_208715281.jpg
#   inflating: image/image_training/image_946714023_product_208715291.jpg
#   inflating: image/image_training/image_946714024_product_208715294.jpg
#   inflating: image/image_training/image_946714026_product_208715303.jpg
#   inflating: image/image_training/image_946714029_product_208715302.jpg
#   inflating: image/image_training/image_946714530_product_208715298.jpg
#   inflating: image/image_training/image_946714532_product_208715295.jpg
#   inflating: image/image_training/image_946714533_product_208715307.jpg
#   inflating: image/image_training/image_946714537_product_208715313.jpg
#   inflating: image/image_training/image_946714538_product_208715284.jpg
#   inflating: image/image_training/image_946714543_product_208715309.jpg
#   inflating: image/image_training/image_946714544_product_208715289.jpg
#   inflating: image/image_training/image_946721447_product_208735305.jpg
#   inflating: image/image_training/image_946721739_product_208735386.jpg
#   inflating: image/image_training/image_946830436_product_208827443.jpg
#   inflating: image/image_training/image_946835695_product_208845661.jpg
#   inflating: image/image_training/image_946841677_product_208730456.jpg
#   inflating: image/image_training/image_946875975_product_208913691.jpg
#   inflating: image/image_training/image_946881096_product_208929813.jpg
#   inflating: image/image_training/image_946890176_product_208944973.jpg
#   inflating: image/image_training/image_946911423_product_209034896.jpg
#   inflating: image/image_training/image_946932405_product_209049661.jpg
#   inflating: image/image_training/image_946944652_product_209067278.jpg
#   inflating: image/image_training/image_947001157_product_209139076.jpg
#   inflating: image/image_training/image_947012265_product_209166191.jpg
#   inflating: image/image_training/image_947015172_product_209167679.jpg
#   inflating: image/image_training/image_947022949_product_209182723.jpg
#   inflating: image/image_training/image_947040701_product_208760997.jpg
#   inflating: image/image_training/image_947063626_product_55046396.jpg
#   inflating: image/image_training/image_947071214_product_46675181.jpg
#   inflating: image/image_training/image_947080313_product_208977262.jpg
#   inflating: image/image_training/image_947080319_product_208977272.jpg
#   inflating: image/image_training/image_947128283_product_97662640.jpg
#   inflating: image/image_training/image_947131876_product_209253278.jpg
#   inflating: image/image_training/image_947132660_product_209253181.jpg
#   inflating: image/image_training/image_947134671_product_209241716.jpg
#   inflating: image/image_training/image_947147483_product_209252641.jpg
#   inflating: image/image_training/image_947159032_product_124775699.jpg
#   inflating: image/image_training/image_947184929_product_126618853.jpg
#   inflating: image/image_training/image_947188622_product_209244791.jpg
#   inflating: image/image_training/image_947188824_product_209342192.jpg
#   inflating: image/image_training/image_947189019_product_209249191.jpg
#   inflating: image/image_training/image_947189380_product_209026723.jpg
#   inflating: image/image_training/image_947189381_product_209026716.jpg
#   inflating: image/image_training/image_947189786_product_209342185.jpg
#   inflating: image/image_training/image_947190002_product_208989628.jpg
#   inflating: image/image_training/image_947191434_product_209153624.jpg
#   inflating: image/image_training/image_947204280_product_208857287.jpg
#   inflating: image/image_training/image_947206925_product_209370105.jpg
#   inflating: image/image_training/image_947212849_product_209379792.jpg
#   inflating: image/image_training/image_947227525_product_209412874.jpg
#   inflating: image/image_training/image_947239430_product_209423751.jpg
#   inflating: image/image_training/image_947336840_product_147373859.jpg
#   inflating: image/image_training/image_947345043_product_209518714.jpg
#   inflating: image/image_training/image_947351200_product_209068266.jpg
#   inflating: image/image_training/image_947358221_product_209339122.jpg
#   inflating: image/image_training/image_947411763_product_209671785.jpg
#   inflating: image/image_training/image_947446256_product_209783732.jpg
#   inflating: image/image_training/image_947459913_product_209824652.jpg
#   inflating: image/image_training/image_947460234_product_209824752.jpg
#   inflating: image/image_training/image_947460235_product_209824653.jpg
#   inflating: image/image_training/image_947460239_product_209824754.jpg
#   inflating: image/image_training/image_947460240_product_209824751.jpg
#   inflating: image/image_training/image_947460243_product_209824756.jpg
#   inflating: image/image_training/image_947460245_product_209824654.jpg
#   inflating: image/image_training/image_947475134_product_209739021.jpg
#   inflating: image/image_training/image_947482007_product_209743462.jpg
#   inflating: image/image_training/image_947541075_product_204055375.jpg
#   inflating: image/image_training/image_947549202_product_209925253.jpg
#   inflating: image/image_training/image_947549484_product_209925478.jpg
#   inflating: image/image_training/image_947562489_product_209955707.jpg
#   inflating: image/image_training/image_947572566_product_155197977.jpg
#   inflating: image/image_training/image_947613309_product_209689239.jpg
#   inflating: image/image_training/image_947617717_product_181461745.jpg
#   inflating: image/image_training/image_947620247_product_209806809.jpg
#   inflating: image/image_training/image_947620276_product_209826796.jpg
#   inflating: image/image_training/image_947711548_product_206216984.jpg
#   inflating: image/image_training/image_947712263_product_210110708.jpg
#   inflating: image/image_training/image_947731199_product_210138610.jpg
#   inflating: image/image_training/image_947738747_product_210128578.jpg
#   inflating: image/image_training/image_947746850_product_179668963.jpg
#   inflating: image/image_training/image_947746907_product_116630865.jpg
#   inflating: image/image_training/image_947749671_product_209896724.jpg
#   inflating: image/image_training/image_947751326_product_99787050.jpg
#   inflating: image/image_training/image_947764097_product_209606981.jpg
#   inflating: image/image_training/image_947767534_product_209642981.jpg
#   inflating: image/image_training/image_947767539_product_209695066.jpg
#   inflating: image/image_training/image_947777598_product_210192148.jpg
#   inflating: image/image_training/image_947784553_product_210194441.jpg
#   inflating: image/image_training/image_947785080_product_210199304.jpg
#   inflating: image/image_training/image_947791946_product_207286236.jpg
#   inflating: image/image_training/image_947808711_product_210254068.jpg
#   inflating: image/image_training/image_947812584_product_210152611.jpg
#   inflating: image/image_training/image_947815052_product_210147526.jpg
#   inflating: image/image_training/image_947819447_product_209895346.jpg
#   inflating: image/image_training/image_947819500_product_209384409.jpg
#   inflating: image/image_training/image_947819502_product_125805514.jpg
#   inflating: image/image_training/image_947836642_product_210137847.jpg
#   inflating: image/image_training/image_947873676_product_18045197.jpg
#   inflating: image/image_training/image_947895852_product_210288815.jpg
#   inflating: image/image_training/image_947905896_product_210335171.jpg
#   inflating: image/image_training/image_947913222_product_210398931.jpg
#   inflating: image/image_training/image_947921366_product_209976619.jpg
#   inflating: image/image_training/image_947931175_product_210420667.jpg
#   inflating: image/image_training/image_947941545_product_210426837.jpg
#   inflating: image/image_training/image_947941608_product_210427214.jpg
#   inflating: image/image_training/image_947947049_product_210414298.jpg
#   inflating: image/image_training/image_947951184_product_210440554.jpg
#   inflating: image/image_training/image_947959330_product_210452373.jpg
#   inflating: image/image_training/image_947959434_product_210452699.jpg
#   inflating: image/image_training/image_947988270_product_210513034.jpg
#   inflating: image/image_training/image_947991778_product_210518459.jpg
#   inflating: image/image_training/image_948000273_product_210533472.jpg
#   inflating: image/image_training/image_948002879_product_210524132.jpg
#   inflating: image/image_training/image_948014949_product_210557553.jpg
#   inflating: image/image_training/image_948020671_product_210549791.jpg
#   inflating: image/image_training/image_948021176_product_210584765.jpg
#   inflating: image/image_training/image_948031750_product_183723318.jpg
#   inflating: image/image_training/image_948065690_product_210693922.jpg
#   inflating: image/image_training/image_948070991_product_210517047.jpg
#   inflating: image/image_training/image_948071410_product_210483933.jpg
#   inflating: image/image_training/image_948071559_product_210561835.jpg
#   inflating: image/image_training/image_948077736_product_166187827.jpg
#   inflating: image/image_training/image_948095138_product_210690956.jpg
#   inflating: image/image_training/image_948102925_product_210765311.jpg
#   inflating: image/image_training/image_948124730_product_210584974.jpg
#   inflating: image/image_training/image_948124848_product_210694062.jpg
#   inflating: image/image_training/image_948125087_product_210748215.jpg
#   inflating: image/image_training/image_948147163_product_210323285.jpg
#   inflating: image/image_training/image_948196892_product_210561779.jpg
#   inflating: image/image_training/image_948200962_product_191515944.jpg
#   inflating: image/image_training/image_948277018_product_210963717.jpg
#   inflating: image/image_training/image_948317622_product_210988249.jpg
#   inflating: image/image_training/image_948423127_product_210674425.jpg
#   inflating: image/image_training/image_948457447_product_210850589.jpg
#   inflating: image/image_training/image_948461618_product_210750215.jpg
#   inflating: image/image_training/image_948471305_product_211079757.jpg
#   inflating: image/image_training/image_948476842_product_211186162.jpg
#   inflating: image/image_training/image_948476867_product_211186170.jpg
#   inflating: image/image_training/image_948476880_product_211186175.jpg
#   inflating: image/image_training/image_948494478_product_211207642.jpg
#   inflating: image/image_training/image_948539936_product_211166080.jpg
#   inflating: image/image_training/image_948539948_product_211266614.jpg
#   inflating: image/image_training/image_948553168_product_211282555.jpg
#   inflating: image/image_training/image_948553170_product_211282557.jpg
#   inflating: image/image_training/image_948578415_product_211293526.jpg
#   inflating: image/image_training/image_948579243_product_5680951.jpg
#   inflating: image/image_training/image_948580134_product_53642875.jpg
#   inflating: image/image_training/image_948580138_product_211299777.jpg
#   inflating: image/image_training/image_948581076_product_211288387.jpg
#   inflating: image/image_training/image_948587814_product_211342151.jpg
#   inflating: image/image_training/image_948600218_product_211326201.jpg
#   inflating: image/image_training/image_948605852_product_211325293.jpg
#   inflating: image/image_training/image_948607058_product_211332197.jpg
#   inflating: image/image_training/image_948608572_product_211334790.jpg
#   inflating: image/image_training/image_948610852_product_194674281.jpg
#   inflating: image/image_training/image_948646932_product_211355064.jpg
#   inflating: image/image_training/image_948654382_product_211411401.jpg
#   inflating: image/image_training/image_948664632_product_211309972.jpg
#   inflating: image/image_training/image_948664718_product_211332574.jpg
#   inflating: image/image_training/image_948679633_product_211397689.jpg
#   inflating: image/image_training/image_948680705_product_211385713.jpg
#   inflating: image/image_training/image_948682956_product_211398779.jpg
#   inflating: image/image_training/image_948730706_product_211455711.jpg
#   inflating: image/image_training/image_948730716_product_211455716.jpg
#   inflating: image/image_training/image_949110757_product_211959637.jpg
#   inflating: image/image_training/image_949120782_product_211963607.jpg
#   inflating: image/image_training/image_949120784_product_211959636.jpg
#   inflating: image/image_training/image_949216210_product_212100383.jpg
#   inflating: image/image_training/image_949216969_product_212091332.jpg
#   inflating: image/image_training/image_949254753_product_212176943.jpg
#   inflating: image/image_training/image_949260904_product_212190754.jpg
#   inflating: image/image_training/image_949260909_product_212190757.jpg
#   inflating: image/image_training/image_949260911_product_212190755.jpg
#   inflating: image/image_training/image_949260913_product_212190756.jpg
#   inflating: image/image_training/image_949272377_product_211787644.jpg
#   inflating: image/image_training/image_949293437_product_212218275.jpg
#   inflating: image/image_training/image_949294388_product_212221284.jpg
#   inflating: image/image_training/image_949304430_product_212230365.jpg
#   inflating: image/image_training/image_949304463_product_212230370.jpg
#   inflating: image/image_training/image_949320905_product_212253890.jpg
#   inflating: image/image_training/image_949320909_product_212253903.jpg
#   inflating: image/image_training/image_949320924_product_212253909.jpg
#   inflating: image/image_training/image_949321013_product_212253877.jpg
#   inflating: image/image_training/image_949321019_product_212253902.jpg
#   inflating: image/image_training/image_949321021_product_212253872.jpg
#   inflating: image/image_training/image_949321029_product_212253900.jpg
#   inflating: image/image_training/image_949321030_product_212253883.jpg
#   inflating: image/image_training/image_949321038_product_212253901.jpg
#   inflating: image/image_training/image_949321044_product_212253881.jpg
#   inflating: image/image_training/image_949370454_product_212091274.jpg
#   inflating: image/image_training/image_949376304_product_211969641.jpg
#   inflating: image/image_training/image_949378202_product_212075296.jpg
#   inflating: image/image_training/image_949380961_product_212334999.jpg
#   inflating: image/image_training/image_949382356_product_212343189.jpg
#   inflating: image/image_training/image_949383355_product_212340857.jpg
#   inflating: image/image_training/image_949383461_product_212342907.jpg
#   inflating: image/image_training/image_949383508_product_212340856.jpg
#   inflating: image/image_training/image_949383574_product_212343037.jpg
#   inflating: image/image_training/image_949383620_product_212343049.jpg
#   inflating: image/image_training/image_949383642_product_212342169.jpg
#   inflating: image/image_training/image_949383758_product_212342743.jpg
#   inflating: image/image_training/image_949383819_product_212341909.jpg
#   inflating: image/image_training/image_949383838_product_212341827.jpg
#   inflating: image/image_training/image_949383973_product_212343154.jpg
#   inflating: image/image_training/image_949384265_product_212342733.jpg
#   inflating: image/image_training/image_949384537_product_212341850.jpg
#   inflating: image/image_training/image_949384556_product_212342740.jpg
#   inflating: image/image_training/image_949384629_product_212342898.jpg
#   inflating: image/image_training/image_949384666_product_212343186.jpg
#   inflating: image/image_training/image_949384786_product_212342748.jpg
#   inflating: image/image_training/image_949384800_product_212343035.jpg
#   inflating: image/image_training/image_949384953_product_212342781.jpg
#   inflating: image/image_training/image_949385010_product_212343039.jpg
#   inflating: image/image_training/image_949385020_product_212342905.jpg
#   inflating: image/image_training/image_949385216_product_212343144.jpg
#   inflating: image/image_training/image_949385314_product_212343045.jpg
#   inflating: image/image_training/image_949385428_product_212342906.jpg
#   inflating: image/image_training/image_949385521_product_212343152.jpg
#   inflating: image/image_training/image_949385572_product_212341939.jpg
#   inflating: image/image_training/image_949385868_product_212342358.jpg
#   inflating: image/image_training/image_949385947_product_212342900.jpg
#   inflating: image/image_training/image_949386053_product_212342777.jpg
#   inflating: image/image_training/image_949386104_product_212343038.jpg
#   inflating: image/image_training/image_949386142_product_212342779.jpg
#   inflating: image/image_training/image_949386156_product_212341777.jpg
#   inflating: image/image_training/image_949386592_product_212342786.jpg
#   inflating: image/image_training/image_949386746_product_212343047.jpg
#   inflating: image/image_training/image_949386765_product_212342805.jpg
#   inflating: image/image_training/image_949386868_product_212343036.jpg
#   inflating: image/image_training/image_949386929_product_212343237.jpg
#   inflating: image/image_training/image_949386947_product_212342899.jpg
#   inflating: image/image_training/image_949387202_product_212342051.jpg
#   inflating: image/image_training/image_949387224_product_212342904.jpg
#   inflating: image/image_training/image_949387247_product_212343188.jpg
#   inflating: image/image_training/image_949387294_product_212341942.jpg
#   inflating: image/image_training/image_949387297_product_212343150.jpg
#   inflating: image/image_training/image_949387363_product_212342803.jpg
#   inflating: image/image_training/image_949387369_product_212341710.jpg
#   inflating: image/image_training/image_949387399_product_212341972.jpg
#   inflating: image/image_training/image_949387427_product_212342729.jpg
#   inflating: image/image_training/image_949387436_product_212343125.jpg
#   inflating: image/image_training/image_949387857_product_212341044.jpg
#   inflating: image/image_training/image_949395708_product_212375870.jpg
#   inflating: image/image_training/image_949396445_product_212375869.jpg
#   inflating: image/image_training/image_949397182_product_166549453.jpg
#   inflating: image/image_training/image_949431665_product_72516875.jpg
#   inflating: image/image_training/image_949436594_product_212435049.jpg
#   inflating: image/image_training/image_949486886_product_212393369.jpg
#   inflating: image/image_training/image_949486887_product_212393370.jpg
#   inflating: image/image_training/image_949498382_product_212509001.jpg
#   inflating: image/image_training/image_949538847_product_212564253.jpg
#   inflating: image/image_training/image_949551795_product_212486241.jpg
#   inflating: image/image_training/image_949552367_product_212583421.jpg
#   inflating: image/image_training/image_949552372_product_212583426.jpg
#   inflating: image/image_training/image_949552374_product_212583425.jpg
#   inflating: image/image_training/image_949552376_product_212583424.jpg
#   inflating: image/image_training/image_949552378_product_212583428.jpg
#   inflating: image/image_training/image_949552382_product_212583423.jpg
#   inflating: image/image_training/image_949552611_product_212529962.jpg
#   inflating: image/image_training/image_949592728_product_59474657.jpg
#   inflating: image/image_training/image_949594246_product_212602002.jpg
#   inflating: image/image_training/image_949594248_product_212496749.jpg
#   inflating: image/image_training/image_949595565_product_212632237.jpg
#   inflating: image/image_training/image_949624744_product_212666346.jpg
#   inflating: image/image_training/image_949660331_product_212653642.jpg
#   inflating: image/image_training/image_949683189_product_212762551.jpg
#   inflating: image/image_training/image_949712102_product_212746587.jpg
#   inflating: image/image_training/image_949740138_product_76206149.jpg
#   inflating: image/image_training/image_949744717_product_212769558.jpg
#   inflating: image/image_training/image_949744897_product_212769655.jpg
#   inflating: image/image_training/image_949746023_product_212770758.jpg
#   inflating: image/image_training/image_949746331_product_212770427.jpg
#   inflating: image/image_training/image_949751394_product_212732223.jpg
#   inflating: image/image_training/image_949752961_product_212780556.jpg
#   inflating: image/image_training/image_949753182_product_212778424.jpg
#   inflating: image/image_training/image_949753634_product_212779437.jpg
#   inflating: image/image_training/image_949765636_product_212791799.jpg
#   inflating: image/image_training/image_949770382_product_212762576.jpg
#   inflating: image/image_training/image_949982892_product_213087646.jpg
#   inflating: image/image_training/image_949998822_product_213166063.jpg
#   inflating: image/image_training/image_950004800_product_213067622.jpg
#   inflating: image/image_training/image_950078807_product_213246566.jpg
#   inflating: image/image_training/image_950090822_product_213235566.jpg
#   inflating: image/image_training/image_950140794_product_213295603.jpg
#   inflating: image/image_training/image_950172788_product_213355584.jpg
#   inflating: image/image_training/image_950384231_product_213614351.jpg
#   inflating: image/image_training/image_950562819_product_74289424.jpg
#   inflating: image/image_training/image_950966772_product_213337645.jpg
#   inflating: image/image_training/image_950968792_product_213209557.jpg
#   inflating: image/image_training/image_950994784_product_51659012.jpg
#   inflating: image/image_training/image_951260818_product_214651638.jpg
#   inflating: image/image_training/image_951528776_product_214721665.jpg
#   inflating: image/image_training/image_951564733_product_61912172.jpg
#   inflating: image/image_training/image_951576730_product_3214438.jpg
#   inflating: image/image_training/image_951686769_product_106383821.jpg
#   inflating: image/image_training/image_951716739_product_215209554.jpg
#   inflating: image/image_training/image_951722798_product_215261555.jpg
#   inflating: image/image_training/image_951840781_product_138768867.jpg
#   inflating: image/image_training/image_951986767_product_215509584.jpg
#   inflating: image/image_training/image_952397754_product_215549708.jpg
#   inflating: image/image_training/image_952397760_product_215549715.jpg
#   inflating: image/image_training/image_952399900_product_215707585.jpg
#   inflating: image/image_training/image_952576380_product_216190307.jpg
#   inflating: image/image_training/image_952639056_product_216196079.jpg
#   inflating: image/image_training/image_952640557_product_216198843.jpg
#   inflating: image/image_training/image_952974857_product_216644798.jpg
#   inflating: image/image_training/image_952988857_product_216644813.jpg
# ...
#   inflating: image/image_training/image_996525377_product_312241356.jpg
#   inflating: image/image_training/image_996536549_product_312364984.jpg
#   inflating: image/image_training/image_996538741_product_311586940.jpg
#   inflating: image/image_training/image_996553391_product_309966911.jpg
#   inflating: image/image_training/image_996553881_product_311555147.jpg
#   inflating: image/image_training/image_996554104_product_222563844.jpg
#   inflating: image/image_training/image_996554110_product_311561340.jpg
#   inflating: image/image_training/image_996627388_product_311762790.jpg
#   inflating: image/image_training/image_996643998_product_314834626.jpg
#   inflating: image/image_training/image_996646453_product_315364218.jpg
#   inflating: image/image_training/image_996671964_product_315566227.jpg
#   inflating: image/image_training/image_996697036_product_316066156.jpg
#   inflating: image/image_training/image_996697041_product_316066155.jpg
#   inflating: image/image_training/image_996710157_product_131458918.jpg
#   inflating: image/image_training/image_996710301_product_316771366.jpg
#   inflating: image/image_training/image_996710819_product_312972304.jpg
#   inflating: image/image_training/image_996711340_product_313178842.jpg
#   inflating: image/image_training/image_996742293_product_317499713.jpg
#   inflating: image/image_training/image_996744514_product_317521591.jpg
#   inflating: image/image_training/image_996751864_product_316778737.jpg
#   inflating: image/image_training/image_996769316_product_185119264.jpg
#   inflating: image/image_training/image_996770100_product_316534932.jpg
#   inflating: image/image_training/image_996778966_product_317591576.jpg
#   inflating: image/image_training/image_996783983_product_319201291.jpg
#   inflating: image/image_training/image_996786120_product_318617846.jpg
#   inflating: image/image_training/image_996801667_product_319269174.jpg
#   inflating: image/image_training/image_996812613_product_315575066.jpg
#   inflating: image/image_training/image_996867609_product_321177391.jpg
#   inflating: image/image_training/image_996896201_product_320641899.jpg
#   inflating: image/image_training/image_996900441_product_321505071.jpg
#   inflating: image/image_training/image_996902116_product_321850161.jpg
#   inflating: image/image_training/image_996927965_product_321600254.jpg
#   inflating: image/image_training/image_996931037_product_323186313.jpg
#   inflating: image/image_training/image_996945375_product_324171186.jpg
#   inflating: image/image_training/image_996955001_product_324596180.jpg
#   inflating: image/image_training/image_996964590_product_324538936.jpg
#   inflating: image/image_training/image_996995846_product_320873766.jpg
#   inflating: image/image_training/image_996998811_product_326605297.jpg
#   inflating: image/image_training/image_997020504_product_326598732.jpg
#   inflating: image/image_training/image_997130335_product_320422886.jpg
#   inflating: image/image_training/image_997138552_product_298932363.jpg
#   inflating: image/image_training/image_997153828_product_67641883.jpg
#   inflating: image/image_training/image_997172758_product_328188055.jpg
#   inflating: image/image_training/image_997177389_product_314654412.jpg
#   inflating: image/image_training/image_997182740_product_320388594.jpg
#   inflating: image/image_training/image_997184297_product_328788150.jpg
#   inflating: image/image_training/image_997192676_product_210237073.jpg
#   inflating: image/image_training/image_997223741_product_328044078.jpg
#   inflating: image/image_training/image_997242353_product_86826922.jpg
#   inflating: image/image_training/image_997276362_product_86419416.jpg
#   inflating: image/image_training/image_997283332_product_209743530.jpg
#   inflating: image/image_training/image_997293558_product_328119149.jpg
#   inflating: image/image_training/image_997323780_product_86788227.jpg
#   inflating: image/image_training/image_997330186_product_85589484.jpg
#   inflating: image/image_training/image_997332749_product_93258101.jpg
#   inflating: image/image_training/image_997335324_product_85446554.jpg
#   inflating: image/image_training/image_997348898_product_53278963.jpg
#   inflating: image/image_training/image_99735230_product_3132266.jpg
#   inflating: image/image_training/image_997376916_product_127228877.jpg
#   inflating: image/image_training/image_997384438_product_67911125.jpg
#   inflating: image/image_training/image_997401153_product_86654550.jpg
#   inflating: image/image_training/image_997419462_product_74529248.jpg
#   inflating: image/image_training/image_997420262_product_86928409.jpg
#   inflating: image/image_training/image_997441026_product_85372885.jpg
#   inflating: image/image_training/image_997445352_product_318479643.jpg
#   inflating: image/image_training/image_997456981_product_326180860.jpg
#   inflating: image/image_training/image_997497701_product_18648935.jpg
#   inflating: image/image_training/image_997504094_product_85429964.jpg
#   inflating: image/image_training/image_997521696_product_52965419.jpg
#   inflating: image/image_training/image_997531111_product_330239241.jpg
#   inflating: image/image_training/image_997552764_product_330203999.jpg
#   inflating: image/image_training/image_997562648_product_67739219.jpg
#   inflating: image/image_training/image_997576384_product_67574428.jpg
#   inflating: image/image_training/image_997587110_product_210668388.jpg
#   inflating: image/image_training/image_997598726_product_77489810.jpg
#   inflating: image/image_training/image_997602835_product_67312551.jpg
#   inflating: image/image_training/image_997603929_product_98574272.jpg
#   inflating: image/image_training/image_997614186_product_85913883.jpg
#   inflating: image/image_training/image_997620858_product_86889335.jpg
#   inflating: image/image_training/image_997623158_product_86422895.jpg
#   inflating: image/image_training/image_997671167_product_331347559.jpg
#   inflating: image/image_training/image_997671169_product_331347556.jpg
#   inflating: image/image_training/image_997678552_product_93409902.jpg
#   inflating: image/image_training/image_997679246_product_74457029.jpg
#   inflating: image/image_training/image_997725435_product_86868357.jpg
#   inflating: image/image_training/image_997725833_product_93643951.jpg
#   inflating: image/image_training/image_997746788_product_86265418.jpg
#   inflating: image/image_training/image_997749981_product_67462707.jpg
#   inflating: image/image_training/image_997816663_product_86353138.jpg
#   inflating: image/image_training/image_997831277_product_92360786.jpg
#   inflating: image/image_training/image_997842131_product_150685670.jpg
#   inflating: image/image_training/image_997858628_product_332155130.jpg
#   inflating: image/image_training/image_997858830_product_332155013.jpg
#   inflating: image/image_training/image_997859009_product_87398453.jpg
#   inflating: image/image_training/image_997877716_product_332542372.jpg
#   inflating: image/image_training/image_997885635_product_332557807.jpg
#   inflating: image/image_training/image_997887917_product_332358881.jpg
#   inflating: image/image_training/image_997903677_product_67824130.jpg
#   inflating: image/image_training/image_997944942_product_332684635.jpg
#   inflating: image/image_training/image_997946927_product_332686220.jpg
#   inflating: image/image_training/image_997973033_product_67240245.jpg
#   inflating: image/image_training/image_998007800_product_86657288.jpg
#   inflating: image/image_training/image_998117168_product_331852564.jpg
#   inflating: image/image_training/image_998133615_product_74534070.jpg
#   inflating: image/image_training/image_998165034_product_67705452.jpg
#   inflating: image/image_training/image_998176650_product_332311987.jpg
#   inflating: image/image_training/image_998267625_product_334492445.jpg
#   inflating: image/image_training/image_998279682_product_334563248.jpg
#   inflating: image/image_training/image_998280599_product_334563014.jpg
#   inflating: image/image_training/image_998280894_product_334562957.jpg
#   inflating: image/image_training/image_998292977_product_334561837.jpg
#   inflating: image/image_training/image_998293011_product_334562723.jpg
#   inflating: image/image_training/image_998293303_product_334563088.jpg
#   inflating: image/image_training/image_998293365_product_334561450.jpg
#   inflating: image/image_training/image_998293381_product_334562483.jpg
#   inflating: image/image_training/image_998293389_product_334561010.jpg
#   inflating: image/image_training/image_998293504_product_334562897.jpg
#   inflating: image/image_training/image_998304584_product_334561471.jpg
#   inflating: image/image_training/image_998304667_product_334688491.jpg
#   inflating: image/image_training/image_998305996_product_334562646.jpg
#   inflating: image/image_training/image_998316908_product_87555116.jpg
#   inflating: image/image_training/image_998318838_product_334560246.jpg
#   inflating: image/image_training/image_998333910_product_334559843.jpg
#   inflating: image/image_training/image_998334542_product_334563105.jpg
#   inflating: image/image_training/image_998351717_product_334563422.jpg
#   inflating: image/image_training/image_998363453_product_321453803.jpg
#   inflating: image/image_training/image_998373974_product_334571319.jpg
#   inflating: image/image_training/image_998391537_product_334572131.jpg
#   inflating: image/image_training/image_998392311_product_334570772.jpg
#   inflating: image/image_training/image_998392484_product_334564034.jpg
#   inflating: image/image_training/image_998392842_product_334564726.jpg
#   inflating: image/image_training/image_998403218_product_52963942.jpg
#   inflating: image/image_training/image_998409078_product_334566565.jpg
#   inflating: image/image_training/image_998409653_product_334571819.jpg
#   inflating: image/image_training/image_998414119_product_85730182.jpg
#   inflating: image/image_training/image_998426235_product_334571796.jpg
#   inflating: image/image_training/image_998427095_product_334563990.jpg
#   inflating: image/image_training/image_998427812_product_334572670.jpg
#   inflating: image/image_training/image_998444151_product_334572136.jpg
#   inflating: image/image_training/image_998444811_product_334571198.jpg
#   inflating: image/image_training/image_998460419_product_334571441.jpg
#   inflating: image/image_training/image_998473220_product_334573269.jpg
#   inflating: image/image_training/image_998473662_product_334571979.jpg
#   inflating: image/image_training/image_998474208_product_334574256.jpg
#   inflating: image/image_training/image_998481634_product_334573703.jpg
#   inflating: image/image_training/image_998481762_product_334575409.jpg
#   inflating: image/image_training/image_998482088_product_334574408.jpg
#   inflating: image/image_training/image_998482120_product_334573708.jpg
#   inflating: image/image_training/image_998482821_product_334574999.jpg
#   inflating: image/image_training/image_998482861_product_334574977.jpg
#   inflating: image/image_training/image_998491305_product_334574039.jpg
#   inflating: image/image_training/image_998491483_product_334573487.jpg
#   inflating: image/image_training/image_998491856_product_334575154.jpg
#   inflating: image/image_training/image_998492329_product_334575028.jpg
#   inflating: image/image_training/image_998492635_product_334573582.jpg
#   inflating: image/image_training/image_998500484_product_334575316.jpg
#   inflating: image/image_training/image_998500493_product_334575463.jpg
#   inflating: image/image_training/image_998501506_product_334575338.jpg
#   inflating: image/image_training/image_998509951_product_334573299.jpg
#   inflating: image/image_training/image_998509963_product_334573701.jpg
#   inflating: image/image_training/image_998510724_product_334573427.jpg
#   inflating: image/image_training/image_998513220_product_334573548.jpg
#   inflating: image/image_training/image_998514592_product_86453025.jpg
#   inflating: image/image_training/image_998554083_product_335713272.jpg
#   inflating: image/image_training/image_998557914_product_52978414.jpg
#   inflating: image/image_training/image_998606726_product_335707614.jpg
#   inflating: image/image_training/image_998609044_product_335717210.jpg
#   inflating: image/image_training/image_998692069_product_52949496.jpg
#   inflating: image/image_training/image_998693417_product_67980064.jpg
#   inflating: image/image_training/image_99877030_product_1949505.jpg
#   inflating: image/image_training/image_998812657_product_85741209.jpg
#   inflating: image/image_training/image_998825889_product_86424972.jpg
#   inflating: image/image_training/image_998921862_product_337817561.jpg
#   inflating: image/image_training/image_998924072_product_87095857.jpg
#   inflating: image/image_training/image_998926770_product_52886189.jpg
#   inflating: image/image_training/image_998936979_product_85894436.jpg
#   inflating: image/image_training/image_998973920_product_338125974.jpg
#   inflating: image/image_training/image_999052195_product_86578075.jpg
#   inflating: image/image_training/image_999063264_product_86122280.jpg
#   inflating: image/image_training/image_999076761_product_334123411.jpg
#   inflating: image/image_training/image_999090548_product_19015533.jpg
#   inflating: image/image_training/image_999101884_product_86972217.jpg
#   inflating: image/image_training/image_999162172_product_339691065.jpg
#   inflating: image/image_training/image_999213929_product_328202941.jpg
#   inflating: image/image_training/image_999233488_product_339921567.jpg
#   inflating: image/image_training/image_999332453_product_341654253.jpg
#   inflating: image/image_training/image_999341997_product_339284924.jpg
#   inflating: image/image_training/image_999345855_product_341609528.jpg
#   inflating: image/image_training/image_999354463_product_341343715.jpg
#   inflating: image/image_training/image_999355517_product_341869230.jpg
#   inflating: image/image_training/image_99936530_product_390718.jpg
#   inflating: image/image_training/image_999365772_product_342122194.jpg
#   inflating: image/image_training/image_999368829_product_342122230.jpg
#   inflating: image/image_training/image_999369243_product_342118963.jpg
#   inflating: image/image_training/image_999369402_product_342118492.jpg
#   inflating: image/image_training/image_999433208_product_343162078.jpg
#   inflating: image/image_training/image_999447704_product_106331179.jpg
#   inflating: image/image_training/image_999448764_product_333513717.jpg
#   inflating: image/image_training/image_999505621_product_5429645.jpg
#   inflating: image/image_training/image_999518368_product_339219787.jpg
#   inflating: image/image_training/image_999523310_product_110331363.jpg
#   inflating: image/image_training/image_999536214_product_343309101.jpg
#   inflating: image/image_training/image_999551194_product_344088783.jpg
#   inflating: image/image_training/image_999569766_product_343309099.jpg
#   inflating: image/image_training/image_999581347_product_344240059.jpg
#   inflating: image/image_training/image_999651682_product_67264781.jpg
#   inflating: image/image_training/image_999689751_product_341551155.jpg
#   inflating: image/image_training/image_999711923_product_345705186.jpg
#   inflating: image/image_training/image_999731918_product_346014174.jpg
#   inflating: image/image_training/image_999734080_product_346044445.jpg
#   inflating: image/image_training/image_999795511_product_347242193.jpg
#   inflating: image/image_training/image_999797209_product_347348753.jpg
#   inflating: image/image_training/image_999810849_product_347242248.jpg
#   inflating: image/image_training/image_999832391_product_348231336.jpg
#   inflating: image/image_training/image_999863354_product_349647227.jpg
#   inflating: image/image_training/image_999978542_product_347529201.jpg
#   inflating: image/image_training/image_999988537_product_351615005.jpg

# %%
pwd
# Out:
# '/content/Rakuten'

# %%
 # !cp '/content/drive/My Drive/Rakuten/data/NewTest.csv' data 
 # !cp '/content/drive/My Drive/Rakuten/data/NewTraining.csv' data 
 # !cp '/content/drive/My Drive/Rakuten/data/catalog_english_taxonomy.tsv' data 
 # !cp '/content/drive/My Drive/Rakuten/data/Y_train.tsv' data 
 # !cp '/content/drive/My Drive/Rakuten/data/X_train.tsv' data

# %% [markdown]
# # 1. Setup

# %% [markdown]
# # 1.1 Using Colab GPU for Training
#
# Since we’ll be training a large neural network it’s best to take advantage of the free GPUs and TPUs that Google offers (in this case we’ll attach a GPU), otherwise training will take a very long time.
#
# A GPU can be added by going to the menu and selecting:
#
# Edit 🡒 Notebook Settings 🡒 Hardware accelerator 🡒 (GPU)

# %%
import os, time, datetime
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import random
import logging
tqdm.pandas()
import seaborn as sns
from sklearn.model_selection import train_test_split
from google.colab import drive

#NN Packages
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, random_split,DataLoader, RandomSampler, SequentialSampler

logger = logging.getLogger(__name__)
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla P100-PCIE-16GB

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun May  9 23:20:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 1.2. Installing the Hugging Face Library - Image Pretrained Models
#
# Install the transformers package from **Hugging Face** which will give us a pytorch interface for working with BERT. This library contains interfaces for other pretrained language models.
#
# We’ve selected the pytorch interface because it strikes a nice balance between the high-level APIs (which are easy to use but don’t provide insight into how things work) and tensorflow code (which contains lots of details but often sidetracks us into lessons about tensorflow, when the purpose here is BERT!).
#
# At the moment, the Hugging Face library seems to be the most widely accepted and powerful pytorch interface for working with BERT. In addition to supporting a variety of different pre-trained transformer models, the library also includes pre-built modifications of these models suited to your specific task.
# E.g "BertForSequenceClassification" that we will be using.
#
# The goal  of the **pretrainedmodels** is to:
#
# -  help to reproduce transfer learning setups
#
# -  access pretrained ConvNets with a unique interface/API inspired by torchvision.

# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install pretrainedmodels
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/d8/b2/57495b5309f09fa501866e225c84532d1fd89536ea62406b2181933fb418/transformers-4.5.1-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 5.1MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 17.0MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 21.4MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.10.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.45 tokenizers-0.10.2 transformers-4.5.1
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 5.7MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95
# Collecting pretrainedmodels
#   Downloading https://files.pythonhosted.org/packages/84/0e/be6a0e58447ac16c938799d49bfb5fb7a80ac35e137547fc6cee2c08c4cf/pretrainedmodels-0.7.4.tar.gz (58kB)
#      |████████████████████████████████| 61kB 3.1MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels) (1.8.1+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels) (0.9.1+cu101)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels) (4.41.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pretrainedmodels) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->pretrainedmodels) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision->pretrainedmodels) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch->pretrainedmodels) (1.15.0)
# Building wheels for collected packages: pretrainedmodels
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp37-none-any.whl size=60963 sha256=2e754bcb7ff61ddd9e159cb252e267977607fd538bcceca315512f138a0bac17
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# Successfully built pretrainedmodels
# Installing collected packages: munch, pretrainedmodels
# Successfully installed munch-2.5.0 pretrainedmodels-0.7.4

# %% [markdown]
# # 2. Dataset Loading and Preprocessing

# %% [markdown]
# # 2.1 Dataset Loading

# %%
text_data_path = '/content/Rakuten/data'
image_data_path = '/content/Rakuten/image'

# %%
class SigirPreprocess():

  def __init__(self, text_data_path):
    
        self.text_data_path = text_data_path
        self.train = None # Merged X_train and Y_train
        self.dict_code_to_id = {}
        self.dict_id_to_code = {}
        self.list_tags = {} #unique type code
        self.sentences = []
        self.labels = []
        self.text_col = None
        self.X_test = None

  def prepare_data(self):
        
        # #loading the Merged, preprocessed text data and test data
        # train = pd.read_csv(self.text_data_path+"/NewTraining.csv")
        # # new_train =  train[train['Description'] != " "]
        # # new_train = new_train[new_train['Description'].notna()]
        # self.train = train

        catalog_eng= pd.read_csv(text_data_path+"/catalog_english_taxonomy.tsv",sep="\t")
        X_train= pd.read_csv(text_data_path+"/X_train.tsv",sep="\t")
        Y_train= pd.read_csv(text_data_path+"/Y_train.tsv",sep="\t")
        
        self.list_tags = list(Y_train['Prdtypecode'].unique())
        for i,tag in enumerate(self.list_tags):
            self.dict_code_to_id[tag] = i 
            self.dict_id_to_code[i]=tag
        print(self.dict_code_to_id)
            
        Y_train['labels']=Y_train['Prdtypecode'].map(self.dict_code_to_id)
        train=pd.merge(left=X_train,right=Y_train,
               how='left',left_on=['Integer_id','Image_id','Product_id'],
               right_on=['Integer_id','Image_id','Product_id'])
        prod_map=pd.Series(catalog_eng['Top level category'].values,
                           index=catalog_eng['Prdtypecode']).to_dict()

        train['product'] = train['Prdtypecode'].map(prod_map)
        train['title_len']=train['Title'].progress_apply(lambda x : len(x.split()) if pd.notna(x) else 0)
        train['desc_len']=train['Description'].progress_apply(lambda x : len(x.split()) if pd.notna(x) else 0)
        train['title_desc_len']=train['title_len'] + train['desc_len']
        train.loc[train['Description'].isnull(), 'Description'] = " "
        train['title_desc'] = train['Title'] + " " + train['Description']
        
        self.train = train

        
  def get_sentences(self, text_col, remove_null_rows=True):

       #get values of a specific column
        self.text_col = text_col        

        new_train = self.train.copy()  
        self.sentences = new_train[text_col].values
        self.labels = new_train['labels'].values


  def prepare_test(self, text_col):
    
        X_test = pd.read_csv(self.text_data_path + "/NewTest.csv")
        self.X_test = X_test
        X_test['title_desc'] = X_test['Title'] + " " + X_test['Description']
        self.test_sentences = X_test[text_col].values
        return self.test_sentences

# %% [markdown]
# # 2.2 Drop Records With No Description

# %%
#Load train and test data (test for specific column)

text_col = 'title_desc'

max_len = 256

num_classes = 27

Preprocess = SigirPreprocess(text_data_path)
Preprocess.prepare_data()
train = Preprocess.train
print("Trian:  ", len(Preprocess.train))


Preprocess.get_sentences(text_col)
print("Labels: ", len(Preprocess.labels))

# X_test = Preprocess.prepare_test(text_col)
# print("Test:   ", len(Preprocess.X_test))
# Out:
# {10: 0, 2280: 1, 50: 2, 1280: 3, 2705: 4, 2522: 5, 2582: 6, 1560: 7, 1281: 8, 1920: 9, 2403: 10, 1140: 11, 2583: 12, 1180: 13, 1300: 14, 2462: 15, 1160: 16, 2060: 17, 40: 18, 60: 19, 1320: 20, 1302: 21, 2220: 22, 2905: 23, 2585: 24, 1940: 25, 1301: 26}
# HBox(children=(FloatProgress(value=0.0, max=84916.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=84916.0), HTML(value='')))
# Trian:   84916
# Labels:  84916

# %%
print(Preprocess.train['Title'].isnull().sum())

print(Preprocess.train['Description'].isnull().sum())

print(Preprocess.train['Image_id'].isnull().sum())

print(Preprocess.train['Product_id'].isnull().sum())

print(Preprocess.train['Prdtypecode'].isnull().sum())

print(Preprocess.train['labels'].isnull().sum())

print(Preprocess.train['product'].isnull().sum()) #top level category

print(Preprocess.train['title_desc'].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
Preprocess.train.isnull().values.any()
# Out:
# False

# %%
Preprocess.train.isnull().sum().sum()
# Out:
# 0

# %%
new_train =  Preprocess.train[Preprocess.train['Description'] != " "]
Preprocess.train = new_train
Preprocess.labels = new_train['labels'].values

print("Numner of records without Null Description:  ",len(Preprocess.train))
print("Numner of corresponding Labels:  ",len(Preprocess.labels))
# Out:
# Numner of records without Null Description:   55116
# Numner of corresponding Labels:   55116

# %%
Preprocess.train
# Out:
#        Integer_id  ...                                         title_desc
# 2               2  ...  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 4               4  ...  La Guerre Des Tuques Luc a des id&eacute;es de...
# 7               7  ...  Conquérant Sept Cahier Couverture Polypro 240 ...
# 9               9  ...  Tente Pliante V3s5-Pro Pvc Blanc - 3 X 4m50 - ...
# 10             10  ...  Eames Inspired Sxw Chair - Pink - Black The ti...
# ...           ...  ...                                                ...
# 84908       84908  ...  Dimmerable Usb Led Lampe De Bureau Réglable Ch...
# 84909       84909  ...  espa - kit complet de nage à contre courant 39...
# 84910       84910  ...  Vêtements Pour Animaux Mode Style Chiens Rayé ...
# 84912       84912  ...  Kit piscine acier NEVADA déco pierre Ø 3.50m x...
# 84914       84914  ...  Table Basse Bois De Récupération Massif Base B...
#
# [55116 rows x 12 columns]

# %% [markdown]
# # View Tokenizer Input

# %%
Preprocess.get_sentences(text_col,True)
sentences = Preprocess.sentences

labels = Preprocess.labels
print(sentences)
# Out:
# ['Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style PILOT STYLE Touch Pen de marque Speedlink est 1 stylet ergonomique pour GamePad Nintendo Wii U.<br> Pour un confort optimal et une précision maximale sur le GamePad de la Wii U: ce grand stylet hautement ergonomique est non seulement parfaitement adapté à votre main mais aussi très élégant.<br> Il est livré avec un support qui se fixe sans adhésif à l\'arrière du GamePad<br> <br> Caractéristiques:<br> Modèle: Speedlink PILOT STYLE Touch Pen<br> Couleur: Bleu<br> Ref. Fabricant: SL-3468-BE<br> Compatibilité: GamePad Nintendo Wii U<br> Forme particulièrement ergonomique excellente tenue en main<br> Pointe à revêtement longue durée conçue pour ne pas abîmer l\'écran tactile<br> En bonus : Support inclu pour GamePad<br> <span class="vga_style2"><b></b><br>'
#  "La Guerre Des Tuques Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de boules de neige et s'arranger pour en &ecirc;tre le vainqueur incontest&eacute;. Mais Sophie s'en m&ecirc;le et chambarde tous ses plans..."
#  'Conquérant Sept Cahier Couverture Polypro 240 X 320 Mm 96 Pages 90g Seyès Incolore CONQUERANT CLASSIQUE Cahier 240 x 320 mm seyès incolorecouverture en Polypro 96 pages agrafé papier de 90 g/m2(400006764)'
#  ...
#  'Vêtements Pour Animaux Mode Style Chiens Rayé T-Shirt Costume Petit Chiot Rouge le t - shirt rayé mode chiens  petits chiots vêtements<ul><li>note: veuillez comparer le détail tailles avec toi avant d acheter.!!utiliser les mêmes</li><li>les vêtements de comparer avec la taille.</li><li>description:</li><li>100% brand new la qualité élevée</li><li>quantité: 1</li><li>matériel: coton</li><li>motif: le</li><li>votre chien est plus élégante cool</li><li>parfait pour la marche  jogging</li><li>attention: comme différents ordinateurs afficher les couleurs différemment  la couleur de la poste peut varier légèrement d images ci - dessus  merci pour votre compréhension.</li><li>toutes les dimensions sont mesurées à la main  il y a peut - être 2-3cm déviations  merci pour ta compréhension</li><li>taille des détails:</li><li>taille: s</li><li>cou: 24 cm / 9 h 45  </li><li>dos: 23cm / 9.06  </li><li>bust: 34cm / 13.39  </li><li>taille: m </li><li>cou: 28 / 11.02  </li><li>dos: isbn / 10 63  </li><li>bust: 40 cm / 15.75</li><li>taille: l</li><li>cou: 34cm / 13.39  </li><li>retour: 31cm / 12.20  </li><li>buste: 44 / 17.32 po</li><li>taille: xl</li><li>cou: 38 cm / 14.96  </li><li>: 37cm / 14.57 po</li><li>bust: 51cm / 20.08  </li><li>taille: xxl</li><li>cou: 42cm / 16.54 po</li><li>: 41cm / 16.14  </li><li>buste: 60 cm / 23.62 po</li><li>forfait comprend:</li><li>le t - shirt 1pcs pet</li><li></li></ul>'
#  'Kit piscine acier NEVADA déco pierre Ø 3.50m x 0.90m <b>Description complète :</b><br />Kit piscine hors-sol Toi PIEDRA GRIS ronde Ø 3.50m hauteur 0.90m. Parois acier liner 30/100eme uni bleu revêtement breveté exclusif imitant la pierre échelle profilés en PVC. Kit piscine complet.<br /><br /><b>Caractéristiques détaillées :</b><br />- Forme : Ronde<br />- Type : Kit piscine acier hors-sol<br />- Dimensions extérieures : Ø3.50 x 0.90m<br />- Surface installation : 3.60m x 3.60m<br />- Hauteur avec margelle : 0.90m<br />- Utilisation : Hors-sol<br />- Capacité : 8m3<br />- Kit complet : Oui<br />- Liner : Uni bleu 30/100e avec fixation overlap<br />- Largeur des margelles : Sans<br />- Structure : Parois acier anti-corrosion<br />- Epaisseur des parois : Acier 35/100eme<br />- Jambes de force : Sans jambes de forces apparentes<br />- Revêtement extérieur : Parois laquées avec décoration pierre &#34;Stone Effect&#34;<br />- Type de filtration : Filtration à cartouche<br />- Débit : 2m³ / heure<br />- Pompe : 46W<br />- Garantie structure : 2 ans<br />- Garantie liner : 2 ans<br />- Garantie filtration : 2 ans<br />- Echelle : Symétrique acier 2 marches<br />- Notice de montage : Oui<br />- Livraison : 1 palette<br />- Garantie : 2 ans<br />'
#  'Table Basse Bois De Récupération Massif Base Blanche 60x60x33cm <p>Cette table basse a un design unique et constituera un ajout intemporel à votre maison. Son dessus de table en bois massif est idéal pour ranger vos boissons panier de fruits ou objets décoratifs et sa base en acier solide ajoute à la robustesse de la table d&#39;appoint. La table basse est faite de bois de récupération massif provenant de solives de planchers et de poutres de soutien de vieux bâtiments en cours de démolition et peut être composée de différents types de bois comme le Sesham (bois de rose) le pin le teck le hêtre le chêne le cèdre le bois de manguier l&#39;acacia etc. Cela signifie que le bois de récupération conserve les caractéristiques de ces différents types de bois. Le bois récupéré est déjà vieilli patiné et séché de sorte qu&#39;il ne rétrécit pas ne se plie pas et n&#39;a pas besoin d&#39;une finition. Chaque étape du processus est réalisée avec le plus grand soin que ce soit le ponçage la peinture ou le laquage. Les belles fibres de bois rendent chaque meuble unique et légèrement différent du suivant. Les signes d&#39;usure et la structure fibreuse visible donnent à chaque pièce son histoire et un aspect unique. L&#39;article est déjà assemblé ; aucun assemblage n&#39;est requis. Remarque importante : les couleurs varient d&#39;un meuble à l&#39;autre rendant chacune de nos tables basses unique la livraison est aléatoire.</p> <ul><li>Couleur de base : Blanc</li><li>Matériau : dessus de table en bois massif de récupération &#43; base en acier</li><li>Dimensions : 60 x 33 cm (Diam. x H)</li><li>Produit poncé peint et laqué</li><li>Aucun assemblage requis</li></ul>']

# %%
print (type(sentences))
print()
print("Total number of sentences:{}, labels:{}".format(len(sentences), len(labels)))
# Out:
# <class 'numpy.ndarray'>
#
# Total number of sentences:55116, labels:55116

# %% [markdown]
# **Helper Function**

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %% [markdown]
# # 3. Tokenization & Input Formatting
#  Transform our dataset into the format that BERT can be trained on.

# %% [markdown]
# # 3.1. BERT Tokenizer
# To feed our text to BERT, it must be split into tokens, and then these tokens must be mapped to their index in the tokenizer vocabulary.
#
# The tokenization must be performed by the tokenizer included within BERT

# %%
from transformers import XLMForSequenceClassification
from transformers import FlaubertModel, FlaubertTokenizer,FlaubertForSequenceClassification,AdamW, FlaubertConfig 

from torch.nn import Dropout,Conv1d, Linear
from transformers.modeling_utils import SequenceSummary

#from transformers.modeling_roberta import RobertaClassificationHead

# %% [markdown]
# # 3.2. Required Formatting
# We are required to give it a number of pieces of information
#
# We need to:
#
# Add special tokens to the start and end of each sentence.
# Pad & truncate all sentences to a single constant length.
# Explicitly differentiate real tokens from padding tokens with the “attention mask”.

# %% [markdown]
# # 3.3. Tokenize Dataset
# We will use "encode_plus":
#
# returns a dictionary containing the encoded sequence or sequence pair and additional information: the mask for sequence classification and the overflowing elements if a max_length is specified.

# %%
def prep_input(sentences,labels, max_len,tokenizer):
    input_ids = []
    attention_masks = []

    # For every sentence...
    for sent in sentences:
        # `encode_plus` will:
        #   (1) Tokenize the sentence.
        #   (2) Prepend the `[CLS]` token to the start.
        #   (3) Append the `[SEP]` token to the end.
        #   (4) Map tokens to their IDs.
        #   (5) Pad or truncate the sentence to `max_length`
        #   (6) Create attention masks for [PAD] tokens.
        encoded_dict = tokenizer.encode_plus(
                            sent,                           # Sentence to encode.
                            add_special_tokens = True,      # Add '[CLS]' and '[SEP]'
                            max_length = max_len,           # Pad & truncate all sentences.
                            pad_to_max_length = True,
                            return_attention_mask = True,   # Construct attn. masks.
                            return_tensors = 'pt',     # Return pytorch tensors.
                       )

        # Add the encoded sentence to the list.    
        input_ids.append(encoded_dict['input_ids'])       # IDs of the the vocabularies in the Model's dictionary

        # And its attention mask (simply differentiates padding from non-padding).
        attention_masks.append(encoded_dict['attention_mask'])

    # Convert the lists into tensors. 
    input_ids = torch.cat(input_ids, dim=0)             # Concatenates the given sequence of seq tensors in the given dimension. 
                                                        # All tensors must  have the same shape 
    attention_masks = torch.cat(attention_masks, dim=0)

    if labels is not None:
        labels = torch.tensor(labels)
        return input_ids, attention_masks, labels
    else:
        return input_ids, attention_masks

# %% [markdown]
# # 3.4. Importing Tokenizers and Input Preparation
#
# - Now it is time to import both Camembert and FlauBERT tokenizers from  pretained package and prepare the input using them.
#
# - Calling prep_input() for each model will result in the corresponding:
#
#
# 1.   **input ids**
# 2.   **attention maks**
# 3.   **labels**

# %%
from transformers import CamembertConfig, CamembertTokenizer, CamembertModel, CamembertForSequenceClassification, AdamW
from transformers import FlaubertModel, FlaubertTokenizer,FlaubertForSequenceClassification,AdamW, FlaubertConfig 

print('Using Camembert')
tokenizer_cam = CamembertTokenizer.from_pretrained('camembert-base', do_lowercase=False)
print('Using Flaubert')
tokenizer_flau = FlaubertTokenizer.from_pretrained('flaubert/flaubert_base_cased', do_lowercase=False)
# Out:
# Using Camembert
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=810912.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1395301.0, style=ProgressStyle(descript…
# Using Flaubert
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1561415.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=895731.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…

# %%
input_ids_cam, attention_masks_cam, labels_cam = prep_input (sentences, labels, max_len, tokenizer_cam)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2079: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
input_ids_flau, attention_masks_flau, labels_flau  = prep_input(sentences,labels, max_len,tokenizer_flau)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2079: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %% [markdown]
# # 3.5. Training & Validation Split
# Divide up our training randomly select **10%** as a validation set off of the training set.
#
# While splitting, we used the following parameters:
#
#
# 1.   **stratify**:
# in this context, stratification means that the train_test_split method returns training and test subsets that have the same proportions of class labels as the input dataset.
# 2.   **random_state**:
# simply sets a seed to the random generator, so that your train-test splits are always deterministic. If you don't set a seed, it is different each time.

# %%
# val_size = 0.1

# tr_inputs_cam, val_inputs_cam, _,_ = train_test_split (input_ids_cam, labels_cam, stratify = labels_cam,    
#                                                             random_state=2020, test_size = val_size)

# tr_masks_cam, val_masks_cam, _,_ =   train_test_split (attention_masks_cam, labels, stratify = labels,        # labels: Preprocess.labels
#                                                             random_state=2020, test_size = val_size)

# tr_inputs_flau, val_inputs_flau, _,_ = train_test_split (input_ids_flau, labels_flau, stratify=labels,
#                                                             random_state=2020, test_size = val_size)

# tr_masks_flau, val_masks_flau, _,_   = train_test_split (attention_masks_flau, labels,stratify=labels_flau,  # labels: Preprocess.labels
#                                                             random_state=2020, test_size = val_size)

# %%
# torch.save(tr_inputs_cam, "tr_inputs_cam.pt")
# torch.save(val_inputs_cam, "val_inputs_cam.pt")
# torch.save(tr_masks_cam, "tr_masks_cam.pt")
# torch.save(val_masks_cam, "val_masks_cam.pt")

# torch.save(tr_inputs_flau, "tr_inputs_flau.pt")
# torch.save(val_inputs_flau, "val_inputs_flau.pt")
# torch.save(tr_masks_flau, "tr_masks_flau.pt")
# torch.save(val_masks_flau, "val_masks_flau.pt")

# %%
# text_input='./'

# tr_inputs_cam = torch.load(text_input + "tr_inputs_cam.pt")
# val_inputs_cam = torch.load(text_input +"val_inputs_cam.pt")
# tr_masks_cam = torch.load(text_input + "tr_masks_cam.pt")
# val_masks_cam = torch.load(text_input + "val_masks_cam.pt")

# tr_inputs_flau = torch.load(text_input + "tr_inputs_flau.pt")
# val_inputs_flau = torch.load(text_input + "val_inputs_flau.pt")
# tr_masks_flau = torch.load(text_input + "tr_masks_flau.pt")
# val_masks_flau = torch.load(text_input + "val_masks_flau.pt")

# %%
tr_inputs, test_inputs_cam, tr_labels, test_labels_cam = train_test_split(input_ids_cam, labels_cam, stratify=labels_cam, random_state=2020,
                                                                test_size = 0.2)

tr_inputs_cam, val_inputs_cam, train_labels, val_labels = train_test_split(tr_inputs, tr_labels, stratify=tr_labels, random_state=2020,
                                                                test_size = 0.15)

tr_masks, test_masks_cam, tr_masks_labels, _ =   train_test_split(attention_masks_cam, labels, stratify=labels, random_state=2020,
                                                                 test_size=0.2)

tr_masks_cam, val_masks_cam, u,v =   train_test_split(tr_masks, tr_masks_labels, stratify=tr_masks_labels, random_state=2020,
                                                                test_size=0.15 )

# %%
tr_inputs, test_inputs_flau, tr_labels, test_labels_flau = train_test_split(input_ids_cam, labels_cam, stratify=labels_cam, random_state=2020,
                                                                test_size = 0.2)

tr_inputs_flau, val_inputs_flau, train_labels, val_labels = train_test_split(tr_inputs, tr_labels, stratify=tr_labels, random_state=2020,
                                                                test_size = 0.15)

tr_masks, test_masks_flau, tr_masks_labels, _ =   train_test_split(attention_masks_cam, labels, stratify=labels, random_state=2020,
                                                                 test_size=0.2)

tr_masks_flau, val_masks_flau, u,v =   train_test_split(tr_masks, tr_masks_labels, stratify=tr_masks_labels, random_state=2020,
                                                                test_size=0.15 )

# %%
torch.save(tr_inputs_cam, "tr_inputs_cam.pt")
torch.save(val_inputs_cam, "val_inputs_cam.pt")
torch.save(tr_masks_cam, "tr_masks_cam.pt")
torch.save(val_masks_cam, "val_masks_cam.pt")
torch.save(test_inputs_cam, "test_inputs_cam.pt")
torch.save(test_masks_cam, "test_masks_cam.pt")


torch.save(tr_inputs_flau, "tr_inputs_flau.pt")
torch.save(val_inputs_flau, "val_inputs_flau.pt")
torch.save(tr_masks_flau, "tr_masks_flau.pt")
torch.save(val_masks_flau, "val_masks_flau.pt")
torch.save(test_inputs_flau, "test_inputs_flau.pt")
torch.save(test_masks_flau, "test_masks_flau.pt")

# %%
text_input='./'

tr_inputs_cam = torch.load(text_input + "tr_inputs_cam.pt")
val_inputs_cam = torch.load(text_input +"val_inputs_cam.pt")
tr_masks_cam = torch.load(text_input + "tr_masks_cam.pt")
val_masks_cam = torch.load(text_input + "val_masks_cam.pt")
input_ids_test_cam = torch.load(text_input + "test_inputs_cam.pt") 
attention_masks_test_cam = torch.load(text_input + "test_masks_cam.pt") 

tr_inputs_flau = torch.load(text_input + "tr_inputs_flau.pt")
val_inputs_flau = torch.load(text_input + "val_inputs_flau.pt")
tr_masks_flau = torch.load(text_input + "tr_masks_flau.pt")
val_masks_flau = torch.load(text_input + "val_masks_flau.pt")
input_ids_test_flau = torch.load(text_input + "test_inputs_flau.pt")
attention_masks_test_flau = torch.load(text_input + "test_masks_flau.pt")

# %% [markdown]
# # 4. Defining Models to be Fused
#
# Now, as our  data has been preprocessed, cleaned and text data was tokenzied , it is ready to be fed to the models.
# - As a first step,  first we need to define and configure the models.

# %% [markdown]
# # 4.1. RESNet Model for Image Processing.
#
# In PyTorch, you always need to define a forward method for your neural network model. But you never have to call it explicitly.
# Here we are defining our image processing class is subclass of nn.Module and is inheriting all methods. In the super class, nn.Module, there is a __call__ method which obtains the forward function from the subclass and calls it.

# %% [markdown]
# # 4.1.1.  Image Processing Model - RESNet50

# %%
from torch.nn import functional as F
import torch.nn as nn
import pretrainedmodels
class SEResnext50_32x4d(nn.Module):
    def __init__(self, pretrained='imagenet'):
        super(SEResnext50_32x4d, self).__init__()
        
        self.base_model = pretrainedmodels.__dict__["se_resnext50_32x4d"](pretrained=None)
        if pretrained is not None:
            self.base_model.load_state_dict(
                self.base_model.load_state_dict(torch.load(resnet_model_path))
                )
            
        self.l0 = nn.Linear(2048, 27)  # Applies a linear transformation to the incoming data
        # batch_size = 2048
    
    def forward(self, image):
        batch_size, _, _, _ = image.shape

        # During the training you will get batches of images, 
        # so your shape in the forward method will get an additional batch dimension at dim0: 
        # [batch_size, channels, height, width].
        
        x = self.base_model.features(image) 

        #extracting feature vector from network after feature leaning 
        #This is the flatten vector 

        x = F.adaptive_avg_pool2d(x, 1).reshape(batch_size, -1) 
        #adaptive_avg_pool2d : Kernel size = (input_size+target_size-1) // target_size rounded up
        #Then the positions of where to apply the kernel are computed as rounded equidistant points between 0 and input_size - kernel_size
        
        out = self.l0(x)

        return out

# %%
class Identity(nn.Module):
  
    def __init__(self):
        super(Identity, self).__init__()
        
    def forward(self, x):
        return x

# %% [markdown]
# # 4.1.2. Instaniating the Image Processing Network
#  Now we create an instance from the SEResnext50_32x4d class that we defined and load the weights from a pretrained model, since the training is done previously.

# %%
#data_path = '/content/drive/My Drive/Rakuten/'

img_model = SEResnext50_32x4d(pretrained=None)
# img_model.load_state_dict(torch.load(os.path.join(data_path, 'models/RESNET_best_model.pt')))

# img_model.cuda()

# %% [markdown]
# # 4.1.3. Prinitng Model's Params

# %%
img_model.l0 = Identity()

# %%
for param in img_model.parameters():
     print(type(param), param.size())
# Out:
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 3, 7, 7])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 64, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 4, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 128, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([16, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([16])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 16, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 64, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 4, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 128, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([16, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([16])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 16, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 4, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 128, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([16, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([16])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 16, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 8, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([32, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([32])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 32, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 8, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([32, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([32])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 32, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 8, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([32, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([32])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 32, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 8, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([32, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([32])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 32, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 16, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 64, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 16, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 64, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 16, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 64, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 16, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 64, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 16, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 64, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 16, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 512, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 64, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 32, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 2048, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048, 128, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 2048, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 32, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 2048, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048, 128, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 2048, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024, 32, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1024])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048, 1024, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 2048, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048, 128, 1, 1])
# <class 'torch.nn.parameter.Parameter'> torch.Size([2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1000, 2048])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1000])

# %% [markdown]
# # 4.1.4. Model's Params Require No Grads
#
# These are just regular tensors, with one very special addition: we tell PyTorch that they require a gradient. This causes PyTorch to record all of the operations done on the tensor, so that it can calculate the gradient during back-propagation automatically!
# As our model is already trained and weights are assigned, then there is no need to calculate the gradients so no need to send them to the optimizer.

# %%
# params are iterators which contain model's parameters. Usually passed to the optimizer
for params in img_model.parameters():
      params.requires_grad = False

# %%
img_model.out_proj = Identity()

# %% [markdown]
# # Image Data Preparation

# %%
# # Data path
# text_data_path = os.path.join('/content/drive/My Drive/Rakuten')
# image_data_path = os.path.join('')

# %%
def get_img_path(img_id, prd_id, path):
    
    pattern = 'image'+'_'+str(img_id)+'_'+'product'+'_'+str(prd_id)+'.jpg'
    return path + pattern

# %%
print(len(Preprocess.train), len(train))
# Out:
# 55116 84916

# %% [markdown]
# # Obtaining & Splitting Images

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

#  train 65%
#  validation 15%
#  test 20%
# (original training) =>  train, test => 80, 20  val_size = 0.2
# (train) => train, val =>  85, 15   val_size = 0.15 


# train_img = train[['Image_id','Product_id','labels','product']]
train_img = Preprocess.train[['Image_id','Product_id','labels','product']] 

train_img['image_path'] = Preprocess.train.progress_apply(lambda x: get_img_path(x['Image_id'], x['Product_id'],
                                                      path = os.path.join(image_data_path, 'image_training/')),axis=1)




tr_df, test_df, tr_labels, test_labels = train_test_split(train_img, train_img['labels'], 
                                           random_state=2020,
                                           test_size = 0.2,
                                           stratify=train_img['labels'])


train_df, val_df, train_labels, val_labels = train_test_split(tr_df, tr_labels, 
                                           random_state=2020,
                                           test_size = 0.15,
                                           stratify=tr_labels)



print("Train: ", len(train_df))
print("Val:   ", len(val_df))
print("Test:  ", len(test_df))
print ("")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=55116.0), HTML(value='')))
# Train:  37478
# Val:    6614
# Test:   11024
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print("Original Images Df:   ",  len(train_img))
print("Train Images DF:      " , len(train_df))
print("Validation Images DF: ",  len(val_df))
# Out:
# Original Images Df:    55116
# Train Images DF:       37478
# Validation Images DF:  6614

# %%
# print (train_img['image_path'][0])

# %% [markdown]
# # Image Data Augmentation
#
# We're going to be making use of Pytorch's transforms for preparing the input images to be used by ouur model.
#
#
#
#
#
# *   We'll need to make sure the images in the training set and validation set are the same size, so we'll be using transforms.Resize
# *   We'll also be doing a little data augmentation, trying to improve the performance of our model by forcing it to learn about images at different angles and crops, so we'll randomly crop and rotate the images.
#
# *    we'll make tensors out of the images, as PyTorch works with tensors.
# *   Finally, we'll normalize the images, which helps the network work with values that may be have a wide range of different values.
#
#
# *   We then compose all our chosen transforms.
#
# It worth mentioning that validation transforms don't have any of the flipping or rotating, as they aren't part of our training set, so the network isn't learning about them

# %%
input_size = 224 # for Resnt

# Applying Transforms to the Data

from torchvision import datasets, models, transforms

image_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.Resize(size=256),
        transforms.CenterCrop(size=input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %% [markdown]
# # Text Processing Models - BertForSequenceClassification
#
# Thankfully, the huggingface pytorch implementation includes a set of interfaces designed for a variety of NLP tasks. Though these interfaces are all built on top of a trained BERT model, each has different top layers and output types designed to accomodate their specific NLP task.
#
# We first want to modify the pre-trained BERT model to give outputs for classification, and then we want to continue training the model on our dataset until that the entire model, end-to-end, is well-suited for our task.
#
# **BertForSequenceClassification** is one of the current of classes provided for fine-tuning.
#
# This is the normal BERT model with an added single linear layer on top for classification that we will use as a sentence classifier. As we feed input data, the entire pre-trained BERT model and the additional untrained classification layer is trained on our specific task.
#
# - Not to forget that Camembet model inherits RobertaModel

# %% [markdown]
# # 4.2 CamemBERT Model

# %%
class vec_output_CamembertForSequenceClassification(CamembertModel):
    config_class = CamembertConfig

    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels

        self.roberta = CamembertModel(config)
        self.dense = nn.Linear(256*config.hidden_size, config.hidden_size)
        self.dropout = nn.Dropout(0.1)
        self.out_proj = nn.Linear(config.hidden_size, config.num_labels)
        self.init_weights()


    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        token_type_ids=None,
        position_ids=None,
        head_mask=None,
        inputs_embeds=None,
        labels=None,
        output_attentions=None,
        output_hidden_states=None,
    ):
        outputs = self.roberta(
            input_ids,
            attention_mask = attention_mask,
            token_type_ids = token_type_ids,
            position_ids = position_ids,
            head_mask = head_mask,
            inputs_embeds=inputs_embeds,
#           output_attentions=output_attentions,
#           output_hidden_states=output_hidden_states,
        )

        sequence_output = outputs[0] #(B,256,768)

        x = sequence_output.view(sequence_output.shape[0], 256*768)

#       x = sequence_output[:, 0, :]  # take <s> token (equiv. to [CLS])-> #(B,768) Image -> (B,2048)

        x = self.dense(x)  # 768 -> 768

        feat= torch.tanh(x) 

        logits = self.out_proj(feat) # 768 -> 27

        outputs = (logits,) + outputs[2:] #3rd element onwards

        return outputs,feat  # (loss), logits, (hidden_states), (attentions)

# %% [markdown]
# # FlauBERT Model

# %%
num_classes = 27

class vec_output_FlaubertForSequenceClassification(FlaubertModel):
    
    config_class = FlaubertConfig
    

    def __init__(self, config):
        super().__init__(config)
        self.transformer = FlaubertModel(config)
        self.sequence_summary = SequenceSummary(config)
        self.init_weights()
        self.dropout =  torch.nn.Dropout(0.1)
        self.classifier = torch.nn.Linear(config.hidden_size, num_classes)


    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        langs=None,
        token_type_ids=None,
        position_ids=None,
        lengths=None,
        cache=None,
        head_mask=None,
        inputs_embeds=None,
        labels=None,
    ):
        
        
        transformer_outputs = self.transformer(
            input_ids,
            attention_mask=attention_mask,
            langs=langs,
            token_type_ids=token_type_ids,
            position_ids=position_ids,
            lengths=lengths,
            cache=cache,
            head_mask=head_mask,
            inputs_embeds=inputs_embeds,
        )

        #output = self.dropout(output)
        output = transformer_outputs[0] 
        vec = output[:,0]
        
        
        #logits
        dense = self.dropout(vec)
        
        #classifier
        logits = self.classifier(dense)
        
        outputs = (logits,) + transformer_outputs[1:]  # Keep new_mems and attention/hidden states if they are here
       
        
        return outputs,dense

# %% [markdown]
# # Dataset Fusion

# %%
# TODO DELELTE IMAGES WITH NO DESCRIPTION
# From the preprocesssed file

# %%
from torch.utils.data import Dataset, DataLoader, Subset
from PIL import Image
import matplotlib.pyplot as plt
import cv2

class FusionDataset(Dataset):
    
    def __init__(self, df, inputs_cam, masks_cam, inputs_flau, masks_flau, transform=None, mode='train'):
        self.df = df
        self.transform   = transform
        self.mode = mode

        self.inputs_cam  = inputs_cam
        self.masks_cam   = masks_cam

        self.inputs_flau  = inputs_flau
        self.masks_flau   = masks_flau
         
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self,idx):
        
        im_path = self.df.iloc[idx]['image_path']
        img= plt.imread(im_path)
        #img = cv2.imread(im_path)
        #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(img)

        if self.transform is not None:
            img = self.transform(img)

        img              = img.cuda()
        input_id_cam     = self.inputs_cam[idx].cuda()
        input_mask_cam   = self.masks_cam[idx].cuda()
        input_id_flau    = self.inputs_flau[idx].cuda()
        input_mask_flau  = self.masks_flau[idx].cuda()
        
        if self.mode =='test':
            return img,input_id_cam,input_mask_cam,input_id_flau,input_mask_flau
            
        else:
            labels = torch.tensor(self.df.iloc[idx]['labels']).cuda()             
            return img,input_id_cam,input_mask_cam,input_id_flau,input_mask_flau,labels

# %%
a1 = torch.randn(3,10,10)

# %%
reduce_dim = nn.Conv1d(in_channels = 10 , out_channels = 1 , kernel_size= 1)

# %%
reduce_dim(a1).view(3,10).shape
# Out:
# torch.Size([3, 10])

# %%
print('Using Camembert')
tokenizer_cam = CamembertTokenizer.from_pretrained('camembert-base', do_lowercase=False)
print('Using Flaubert')

tokenizer_flau = FlaubertTokenizer.from_pretrained('flaubert/flaubert_base_cased', do_lowercase=False)

# input_ids_test_flau,attention_masks_test_flau = prep_input(test_sentences, labels=None, max_len=max_len,tokenizer = tokenizer_flau)

# input_ids_test_cam,attention_masks_test_cam = prep_input(test_sentences , labels=None, max_len=max_len,tokenizer = tokenizer_cam)
# Out:
# Using Camembert
# Using Flaubert

# %%
# print(type(Preprocess.test_sentences))
# print(len(Preprocess.test_sentences))

# %%
# Moodels path 
resnet_model_path = '/content/Rakuten/models/RESNET_baseline_model.pt' 
camembert_model_path = '/content/Rakuten/models/CamemBERT_best_model_baseline.pt' 
flaubert_model_path = '/content/Rakuten/models/FlauBERT_best_model_baseline.pt'

#my_flau_path  = '/content/Rakuten/models/FlauBERT_best_model_description.pt'

# %% [markdown]
# # Fuse
#  When using pretrained models, PyTorch sets the model to be unfrozen (will have its weights adjusted) by default

# %%
class vector_fusion(nn.Module):    
    def __init__(self):
        super(vector_fusion, self).__init__()

        self.img_model = SEResnext50_32x4d(pretrained=None)
        self.img_model.load_state_dict(torch.load(resnet_model_path))
        self.img_model.l0=Identity()
        for params in self.img_model.parameters():
            params.requires_grad=False

        self.cam_model= vec_output_CamembertForSequenceClassification.from_pretrained(
         'camembert-base', # Use the 12-layer BERT model, with an uncased vocab.
          num_labels = 27, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
          output_attentions = False, # Whether the model returns attentions weights.
          output_hidden_states = False,) # Whether the model returns all hidden-states.
        
        
        checkpoint = torch.load(camembert_model_path)
        self.cam_model.load_state_dict(checkpoint)

        

        for param in self.cam_model.parameters():
            param.requires_grad=False
        self.cam_model.out_proj=Identity()
        
        self.flau_model = vec_output_FlaubertForSequenceClassification.from_pretrained(
        'flaubert/flaubert_base_cased', 
        num_labels = 27, 
        output_attentions = False,
        output_hidden_states = False,)
        checkpoint = torch.load(flaubert_model_path)
        self.flau_model.load_state_dict(checkpoint)

        for param in self.flau_model.parameters():
            param.requires_grad=False
        self.flau_model.classifier=Identity()
        

        self.reduce_dim=nn.Conv1d(in_channels = 2048 , out_channels = 768 , kernel_size= 1)
        self.reduce_dim2=nn.Conv1d(in_channels = 768 , out_channels = 1 , kernel_size= 1)
        self.out=nn.Linear(768*3, 27)
        
        #gamma
#         self.w1 = nn.Parameter(torch.zeros(1))
#         self.w2 = nn.Parameter(torch.zeros(1))
#         self.w3 = nn.Parameter(torch.zeros(1))
        
    def forward(self,img,input_id_cam,input_mask_cam,input_id_flau,input_mask_flau):
        
        cam_emb,vec1 =self.cam_model(input_id_cam, 
                     token_type_ids=None, 
                     attention_mask=input_mask_cam)
        
        flau_emb,vec2 =self.flau_model(input_id_flau, 
                     token_type_ids=None, 
                     attention_mask=input_mask_flau)
        
        #Projecting the image embedding to lower dimension
        img_emb = self.img_model(img)
        
        img_emb = img_emb.view(img_emb.shape[0],img_emb.shape[1],1)
        img_emb = self.reduce_dim(img_emb)
        img_emb = img_emb.view(img_emb.shape[0],img_emb.shape[1]) ###### bs * 768 
        
        #summing up the vectors
        #text_emb = cam_emb[0] + flau_emb[0]
        
        #Bilinear
        #text_emb = text_emb.view(text_emb.shape[0],1,text_emb.shape[1])  ##### bs * 1 * 768
        
        #Bilinear Pooling
        #pool_emb = torch.bmm(img_emb,text_emb) ### bs * 768 * 768
        #pool_emb = self.reduce_dim2(pool_emb).view(text_emb.shape[0],768)  #### bs * 1 * 768
        
        fuse= torch.cat([img_emb,cam_emb[0],flau_emb[0]],axis=1)
        
        
        logits=self.out(fuse)
        return logits

# %%
 img_model = SEResnext50_32x4d(pretrained=None)
 img_model.load_state_dict(torch.load(resnet_model_path))
# Out:
# <All keys matched successfully>

# %%
cam_model= vec_output_CamembertForSequenceClassification.from_pretrained(
         'camembert-base', # Use the 12-layer BERT model, with an uncased vocab.
          num_labels = 27, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
          output_attentions = False, # Whether the model returns attentions weights.
          output_hidden_states = False,) # Whether the model returns all hidden-states.
        
        
checkpoint = torch.load(camembert_model_path)
cam_model.load_state_dict(checkpoint)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=508.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=445032417.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at camembert-base were not used when initializing vec_output_CamembertForSequenceClassification: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing vec_output_CamembertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing vec_output_CamembertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of vec_output_CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['embeddings.word_embeddings.weight', 'embeddings.position_embeddings.weight', 'embeddings.token_type_embeddings.weight', 'embeddings.LayerNorm.weight', 'embeddings.LayerNorm.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.2.attention.self.query.bias', 'encoder.layer.2.attention.self.key.weight', 'encoder.layer.2.attention.self.key.bias', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.2.attention.output.dense.bias', 'encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.output.LayerNorm.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.3.attention.self.query.weight', 'encoder.layer.3.attention.self.query.bias', 'encoder.layer.3.attention.self.key.weight', 'encoder.layer.3.attention.self.key.bias', 'encoder.layer.3.attention.self.value.weight', 'encoder.layer.3.attention.self.value.bias', 'encoder.layer.3.attention.output.dense.weight', 'encoder.layer.3.attention.output.dense.bias', 'encoder.layer.3.attention.output.LayerNorm.weight', 'encoder.layer.3.attention.output.LayerNorm.bias', 'encoder.layer.3.intermediate.dense.weight', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.3.output.dense.weight', 'encoder.layer.3.output.dense.bias', 'encoder.layer.3.output.LayerNorm.weight', 'encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.4.attention.self.query.weight', 'encoder.layer.4.attention.self.query.bias', 'encoder.layer.4.attention.self.key.weight', 'encoder.layer.4.attention.self.key.bias', 'encoder.layer.4.attention.self.value.weight', 'encoder.layer.4.attention.self.value.bias', 'encoder.layer.4.attention.output.dense.weight', 'encoder.layer.4.attention.output.dense.bias', 'encoder.layer.4.attention.output.LayerNorm.weight', 'encoder.layer.4.attention.output.LayerNorm.bias', 'encoder.layer.4.intermediate.dense.weight', 'encoder.layer.4.intermediate.dense.bias', 'encoder.layer.4.output.dense.weight', 'encoder.layer.4.output.dense.bias', 'encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.4.output.LayerNorm.bias', 'encoder.layer.5.attention.self.query.weight', 'encoder.layer.5. ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <All keys matched successfully>

# %%
flau_model = vec_output_FlaubertForSequenceClassification.from_pretrained(
        'flaubert/flaubert_base_cased', 
        num_labels = 27, 
        output_attentions = False,
        output_hidden_states = False,)


checkpoint = torch.load(flaubert_model_path)
flau_model.load_state_dict(checkpoint)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1496.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=553238687.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at flaubert/flaubert_base_cased were not used when initializing vec_output_FlaubertForSequenceClassification: ['pred_layer.proj.bias', 'pred_layer.proj.weight']
# - This IS expected if you are initializing vec_output_FlaubertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing vec_output_FlaubertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of vec_output_FlaubertForSequenceClassification were not initialized from the model checkpoint at flaubert/flaubert_base_cased and are newly initialized: ['position_embeddings.weight', 'embeddings.weight', 'layer_norm_emb.weight', 'layer_norm_emb.bias', 'attentions.0.q_lin.weight', 'attentions.0.q_lin.bias', 'attentions.0.k_lin.weight', 'attentions.0.k_lin.bias', 'attentions.0.v_lin.weight', 'attentions.0.v_lin.bias', 'attentions.0.out_lin.weight', 'attentions.0.out_lin.bias', 'attentions.1.q_lin.weight', 'attentions.1.q_lin.bias', 'attentions.1.k_lin.weight', 'attentions.1.k_lin.bias', 'attentions.1.v_lin.weight', 'attentions.1.v_lin.bias', 'attentions.1.out_lin.weight', 'attentions.1.out_lin.bias', 'attentions.2.q_lin.weight', 'attentions.2.q_lin.bias', 'attentions.2.k_lin.weight', 'attentions.2.k_lin.bias', 'attentions.2.v_lin.weight', 'attentions.2.v_lin.bias', 'attentions.2.out_lin.weight', 'attentions.2.out_lin.bias', 'attentions.3.q_lin.weight', 'attentions.3.q_lin.bias', 'attentions.3.k_lin.weight', 'attentions.3.k_lin.bias', 'attentions.3.v_lin.weight', 'attentions.3.v_lin.bias', 'attentions.3.out_lin.weight', 'attentions.3.out_lin.bias', 'attentions.4.q_lin.weight', 'attentions.4.q_lin.bias', 'attentions.4.k_lin.weight', 'attentions.4.k_lin.bias', 'attentions.4.v_lin.weight', 'attentions.4.v_lin.bias', 'attentions.4.out_lin.weight', 'attentions.4.out_lin.bias', 'attentions.5.q_lin.weight', 'attentions.5.q_lin.bias', 'attentions.5.k_lin.weight', 'attentions.5.k_lin.bias', 'attentions.5.v_lin.weight', 'attentions.5.v_lin.bias', 'attentions.5.out_lin.weight', 'attentions.5.out_lin.bias', 'attentions.6.q_lin.weight', 'attentions.6.q_lin.bias', 'attentions.6.k_lin.weight', 'attentions.6.k_lin.bias', 'attentions.6.v_lin.weight', 'attentions.6.v_lin.bias', 'attentions.6.out_lin.weight', 'attentions.6.out_lin.bias', 'attentions.7.q_lin.weight', 'attentions.7.q_lin.bias', 'attentions.7.k_lin.weight', 'attentions.7.k_lin.bias', 'attentions.7.v_lin.weight', 'attentions.7.v_lin.bias', 'attentions.7.out_lin.weight', 'attentions.7.out_lin.bias', 'attentions.8.q_lin.weight', 'attentions.8.q_lin.bias', 'attentions.8.k_lin.weight', 'attentions.8.k_lin.bias', 'attentions.8.v_lin.weight', 'attentions.8.v_lin.bias', 'attentions.8.out_lin.weight', 'attentions.8.out_lin.bias', 'attentions.9.q_lin.weight', 'attentions.9.q_lin.bias', 'attentions.9.k_lin.weight', 'attentions.9.k_lin.bias', 'attentions.9.v_lin.weight', 'attentions.9.v_lin.bias', 'attentions.9.out_lin.weight', 'attentions.9.out_lin.bias', 'attentions.10.q_lin.weight', 'attentions.10.q_lin.bias', 'attentions.10.k_lin.weight', 'attentions.10.k_lin.bias', 'attentions.10.v_lin.weight', 'attentions.10.v_lin.bias', 'attentions.10.out_lin.weight', 'attentions.10.out_lin.bias', 'attentions.11.q_lin.weight', 'attentions.11.q_lin.bias', 'attentions.11.k_lin.weight', 'attentions.11.k_lin.bias', 'attentions.11.v_lin.weight', 'attentions.11.v_lin.bias', 'attentions.11.out_lin.weight', 'attentions.11.out_lin.bias', 'layer_norm1.0.weight', 'layer_norm1.0.bias', 'layer_norm1.1.weight', 'layer_norm1.1.bias', 'layer_norm1.2.weight', 'layer_norm1.2.bias', 'layer_norm1.3.weight', 'layer_norm1.3.bias', 'layer_norm1.4.weight', 'layer_norm1.4.bias', 'layer_norm1.5.weight', 'layer_norm1.5.bias', 'layer_norm1.6.weight', 'layer_norm1.6.bias', 'layer_norm1.7.weight', 'layer_norm1.7.bias', 'layer_norm1.8.weight', 'layer_norm1.8.bias', 'layer_norm1.9.weight', 'layer_norm1.9.bias', 'layer_norm1.10.weight', 'layer_norm1.10.bias', 'layer_norm1.11.weight', 'layer_norm1.11.bias', 'ffns.0.lin1.weight', 'ffns.0.lin1.bias', 'ffns.0.lin2.weight', 'ffns.0.lin2.bias', 'ffns.1.lin1.weight', 'ffns.1.lin1.bias', 'ffns.1.lin2.weight', 'ffns.1.lin2.bias', 'ffns.2.lin1.weight', 'ffns.2.lin1.bias', 'ffns.2.lin2.weight', 'ffns.2.lin2.bias', 'ffns.3.lin1.weight', 'ffns.3.lin1.bias', 'ffns.3.lin2.weight', 'ffns.3.lin2.bias', 'ffns.4.lin1.weight', 'ffns.4.lin1.bias', 'ffns.4.lin2.weight', 'ffns.4.lin2.bias', 'ffns ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <All keys matched successfully>

# %% [markdown]
# #  Instantiation  & Training of Fusion Model

# %%
model = vector_fusion()
# Out:
# Some weights of the model checkpoint at camembert-base were not used when initializing vec_output_CamembertForSequenceClassification: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing vec_output_CamembertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing vec_output_CamembertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of vec_output_CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['embeddings.word_embeddings.weight', 'embeddings.position_embeddings.weight', 'embeddings.token_type_embeddings.weight', 'embeddings.LayerNorm.weight', 'embeddings.LayerNorm.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.2.attention.self.query.bias', 'encoder.layer.2.attention.self.key.weight', 'encoder.layer.2.attention.self.key.bias', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.2.attention.output.dense.bias', 'encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.output.LayerNorm.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.3.attention.self.query.weight', 'encoder.layer.3.attention.self.query.bias', 'encoder.layer.3.attention.self.key.weight', 'encoder.layer.3.attention.self.key.bias', 'encoder.layer.3.attention.self.value.weight', 'encoder.layer.3.attention.self.value.bias', 'encoder.layer.3.attention.output.dense.weight', 'encoder.layer.3.attention.output.dense.bias', 'encoder.layer.3.attention.output.LayerNorm.weight', 'encoder.layer.3.attention.output.LayerNorm.bias', 'encoder.layer.3.intermediate.dense.weight', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.3.output.dense.weight', 'encoder.layer.3.output.dense.bias', 'encoder.layer.3.output.LayerNorm.weight', 'encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.4.attention.self.query.weight', 'encoder.layer.4.attention.self.query.bias', 'encoder.layer.4.attention.self.key.weight', 'encoder.layer.4.attention.self.key.bias', 'encoder.layer.4.attention.self.value.weight', 'encoder.layer.4.attention.self.value.bias', 'encoder.layer.4.attention.output.dense.weight', 'encoder.layer.4.attention.output.dense.bias', 'encoder.layer.4.attention.output.LayerNorm.weight', 'encoder.layer.4.attention.output.LayerNorm.bias', 'encoder.layer.4.intermediate.dense.weight', 'encoder.layer.4.intermediate.dense.bias', 'encoder.layer.4.output.dense.weight', 'encoder.layer.4.output.dense.bias', 'encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.4.output.LayerNorm.bias', 'encoder.layer.5.attention.self.query.weight', 'encoder.layer.5. ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at flaubert/flaubert_base_cased were not used when initializing vec_output_FlaubertForSequenceClassification: ['pred_layer.proj.bias', 'pred_layer.proj.weight']
# - This IS expected if you are initializing vec_output_FlaubertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing vec_output_FlaubertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of vec_output_FlaubertForSequenceClassification were not initialized from the model checkpoint at flaubert/flaubert_base_cased and are newly initialized: ['position_embeddings.weight', 'embeddings.weight', 'layer_norm_emb.weight', 'layer_norm_emb.bias', 'attentions.0.q_lin.weight', 'attentions.0.q_lin.bias', 'attentions.0.k_lin.weight', 'attentions.0.k_lin.bias', 'attentions.0.v_lin.weight', 'attentions.0.v_lin.bias', 'attentions.0.out_lin.weight', 'attentions.0.out_lin.bias', 'attentions.1.q_lin.weight', 'attentions.1.q_lin.bias', 'attentions.1.k_lin.weight', 'attentions.1.k_lin.bias', 'attentions.1.v_lin.weight', 'attentions.1.v_lin.bias', 'attentions.1.out_lin.weight', 'attentions.1.out_lin.bias', 'attentions.2.q_lin.weight', 'attentions.2.q_lin.bias', 'attentions.2.k_lin.weight', 'attentions.2.k_lin.bias', 'attentions.2.v_lin.weight', 'attentions.2.v_lin.bias', 'attentions.2.out_lin.weight', 'attentions.2.out_lin.bias', 'attentions.3.q_lin.weight', 'attentions.3.q_lin.bias', 'attentions.3.k_lin.weight', 'attentions.3.k_lin.bias', 'attentions.3.v_lin.weight', 'attentions.3.v_lin.bias', 'attentions.3.out_lin.weight', 'attentions.3.out_lin.bias', 'attentions.4.q_lin.weight', 'attentions.4.q_lin.bias', 'attentions.4.k_lin.weight', 'attentions.4.k_lin.bias', 'attentions.4.v_lin.weight', 'attentions.4.v_lin.bias', 'attentions.4.out_lin.weight', 'attentions.4.out_lin.bias', 'attentions.5.q_lin.weight', 'attentions.5.q_lin.bias', 'attentions.5.k_lin.weight', 'attentions.5.k_lin.bias', 'attentions.5.v_lin.weight', 'attentions.5.v_lin.bias', 'attentions.5.out_lin.weight', 'attentions.5.out_lin.bias', 'attentions.6.q_lin.weight', 'attentions.6.q_lin.bias', 'attentions.6.k_lin.weight', 'attentions.6.k_lin.bias', 'attentions.6.v_lin.weight', 'attentions.6.v_lin.bias', 'attentions.6.out_lin.weight', 'attentions.6.out_lin.bias', 'attentions.7.q_lin.weight', 'attentions.7.q_lin.bias', 'attentions.7.k_lin.weight', 'attentions.7.k_lin.bias', 'attentions.7.v_lin.weight', 'attentions.7.v_lin.bias', 'attentions.7.out_lin.weight', 'attentions.7.out_lin.bias', 'attentions.8.q_lin.weight', 'attentions.8.q_lin.bias', 'attentions.8.k_lin.weight', 'attentions.8.k_lin.bias', 'attentions.8.v_lin.weight', 'attentions.8.v_lin.bias', 'attentions.8.out_lin.weight', 'attentions.8.out_lin.bias', 'attentions.9.q_lin.weight', 'attentions.9.q_lin.bias', 'attentions.9.k_lin.weight', 'attentions.9.k_lin.bias', 'attentions.9.v_lin.weight', 'attentions.9.v_lin.bias', 'attentions.9.out_lin.weight', 'attentions.9.out_lin.bias', 'attentions.10.q_lin.weight', 'attentions.10.q_lin.bias', 'attentions.10.k_lin.weight', 'attentions.10.k_lin.bias', 'attentions.10.v_lin.weight', 'attentions.10.v_lin.bias', 'attentions.10.out_lin.weight', 'attentions.10.out_lin.bias', 'attentions.11.q_lin.weight', 'attentions.11.q_lin.bias', 'attentions.11.k_lin.weight', 'attentions.11.k_lin.bias', 'attentions.11.v_lin.weight', 'attentions.11.v_lin.bias', 'attentions.11.out_lin.weight', 'attentions.11.out_lin.bias', 'layer_norm1.0.weight', 'layer_norm1.0.bias', 'layer_norm1.1.weight', 'layer_norm1.1.bias', 'layer_norm1.2.weight', 'layer_norm1.2.bias', 'layer_norm1.3.weight', 'layer_norm1.3.bias', 'layer_norm1.4.weight', 'layer_norm1.4.bias', 'layer_norm1.5.weight', 'layer_norm1.5.bias', 'layer_norm1.6.weight', 'layer_norm1.6.bias', 'layer_norm1.7.weight', 'layer_norm1.7.bias', 'layer_norm1.8.weight', 'layer_norm1.8.bias', 'layer_norm1.9.weight', 'layer_norm1.9.bias', 'layer_norm1.10.weight', 'layer_norm1.10.bias', 'layer_norm1.11.weight', 'layer_norm1.11.bias', 'ffns.0.lin1.weight', 'ffns.0.lin1.bias', 'ffns.0.lin2.weight', 'ffns.0.lin2.bias', 'ffns.1.lin1.weight', 'ffns.1.lin1.bias', 'ffns.1.lin2.weight', 'ffns.1.lin2.bias', 'ffns.2.lin1.weight', 'ffns.2.lin1.bias', 'ffns.2.lin2.weight', 'ffns.2.lin2.bias', 'ffns.3.lin1.weight', 'ffns.3.lin1.bias', 'ffns.3.lin2.weight', 'ffns.3.lin2.bias', 'ffns.4.lin1.weight', 'ffns.4.lin1.bias', 'ffns.4.lin2.weight', 'ffns.4.lin2.bias', 'ffns ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.cuda()
# Out:
# vector_fusion(
#   (img_model): SEResnext50_32x4d(
#     (base_model): SENet(
#       (layer0): Sequential(
#         (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#       )
#       (layer1): Sequential(
#         (0): SEResNeXtBottleneck(
#           (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEResNeXtBottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (2): SEResNeXtBottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (layer2): Sequential(
#         (0): SEResNeXtBottleneck(
#           (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEResNeXtBottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (2): SEResNeXtBottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (3): SEResNeXtBottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (layer3): Sequential(
#         (0): SEResNeXtBottleneck(
#           (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEResNeXtBottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (2): SEResNeXtBottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (3): SEResNeXtBottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (4): SEResNeXtBottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (5): SEResNeXtBottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (layer4): Sequential(
#         (0): SEResNeXtBottleneck(
#           (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEResNeXtBottleneck(
#           (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (2): SEResNeXtBottleneck(
#           (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se_module): SEModule(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace=True)
#             (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (avg_pool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#       (last_linear): Linear(in_features=2048, out_features=1000, bias=True)
#     )
#     (l0): Identity()
#   )
#   (cam_model): vec_output_CamembertForSequenceClassification(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(32005, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#     (roberta): CamembertModel(
#       (embeddings): RobertaEmbeddings(
#         (word_embeddings): Embedding(32005, 768, padding_idx=1)
#         (position_embeddings): Embedding(514, 768, padding_idx=1)
#         (token_type_embeddings): Embedding(1, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): RobertaEncoder(
#         (layer): ModuleList(
#           (0): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): RobertaSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): RobertaOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): RobertaPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#     (dense): Linear(in_features=196608, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Identity()
#   )
#   (flau_model): vec_output_FlaubertForSequenceClassification(
#     (position_embeddings): Embedding(512, 768)
#     (embeddings): Embedding(68729, 768, padding_idx=2)
#     (layer_norm_emb): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (attentions): ModuleList(
#       (0): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (1): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (2): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (3): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (4): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (5): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (6): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (7): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (8): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (9): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (10): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#       (11): MultiHeadAttention(
#         (q_lin): Linear(in_features=768, out_features=768, bias=True)
#         (k_lin): Linear(in_features=768, out_features=768, bias=True)
#         (v_lin): Linear(in_features=768, out_features=768, bias=True)
#         (out_lin): Linear(in_features=768, out_features=768, bias=True)
#       )
#     )
#     (layer_norm1): ModuleList(
#       (0): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (1): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (3): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (4): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (5): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (6): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (7): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (8): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (9): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (10): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (11): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     )
#     (ffns): ModuleList(
#       (0): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (1): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (2): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (3): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (4): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (5): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (6): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (7): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (8): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (9): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (10): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#       (11): TransformerFFN(
#         (lin1): Linear(in_features=768, out_features=3072, bias=True)
#         (lin2): Linear(in_features=3072, out_features=768, bias=True)
#       )
#     )
#     (layer_norm2): ModuleList(
#       (0): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (1): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (3): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (4): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (5): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (6): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (7): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (8): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (9): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (10): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (11): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     )
#     (transformer): FlaubertModel(
#       (position_embeddings): Embedding(512, 768)
#       (embeddings): Embedding(68729, 768, padding_idx=2)
#       (layer_norm_emb): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (attentions): ModuleList(
#         (0): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (1): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (2): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (3): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (4): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (5): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (6): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (7): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (8): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (9): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (10): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (11): MultiHeadAttention(
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#       )
#       (layer_norm1): ModuleList(
#         (0): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (1): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (3): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (4): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (5): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (6): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (7): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (8): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (9): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (10): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (11): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (ffns): ModuleList(
#         (0): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (1): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (2): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (3): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (4): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (5): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (6): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (7): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (8): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (9): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (10): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (11): TransformerFFN(
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (layer_norm2): ModuleList(
#         (0): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (1): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (3): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (4): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (5): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (6): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (7): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (8): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (9): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (10): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (11): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#     (sequence_summary): SequenceSummary(
#       (summary): Linear(in_features=768, out_features=27, bias=True)
#       (activation): Identity()
#       (first_dropout): Dropout(p=0.1, inplace=False)
#       (last_dropout): Identity()
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#     (classifier): Identity()
#   )
#   (reduce_dim): Conv1d(2048, 768, kernel_size=(1,), stride=(1,))
#   (reduce_dim2): Conv1d(768, 1, kernel_size=(1,), stride=(1,))
#   (out): Linear(in_features=2304, out_features=27, bias=True)
# )

# %% [markdown]
# # Fuse Input Data

# %%
train_dataset = FusionDataset (train_df, tr_inputs_cam, tr_masks_cam, tr_inputs_flau, tr_masks_flau,
                            transform = image_transforms['train'])

val_dataset = FusionDataset (val_df, val_inputs_cam, val_masks_cam, val_inputs_flau, val_masks_flau,
                          transform = image_transforms['valid'])

test_dataset = FusionDataset (test_df, input_ids_test_cam, attention_masks_test_cam, input_ids_test_flau, attention_masks_test_flau
                           , transform = image_transforms['test'])

# %%
print(len(train_df), len(tr_inputs_cam), len(tr_inputs_flau))
# Out:
# 37478 37478 37478

# %% [markdown]
# # Data Loaders
#
# We need to use the DataLoaders to create iterable objects for us to work with. We tell it which datasets we want to use, give it a batch size, and shuffle the data

# %%
batch_size = 32 #increase batch size to reduce the noise 

train_dataloader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True)

validation_dataloader = DataLoader(val_dataset,batch_size=batch_size,shuffle=False)
 
test_dataloader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False)

# %%
import torch.nn as nn
loss_criterion = nn.CrossEntropyLoss()

# %%
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
model_path =  '/content/drive/My Drive/Rakuten/models/baseline_final_fusion.pt'

# %%
checkpoint = torch.load(model_path)
model.load_state_dict(checkpoint) # A state_dict is simply a Python dictionary object 
                                  # that maps each layer to its parameter tensor
# Out:
# <All keys matched successfully>

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score


def predict_pyt(model, prediction_dataloader):
    """
    model: pytorch model
    prediction_dataloader: DataLoader object for which the predictions has to be made.
    return:
        predictions:    - Direct predicted labels
        softmax_logits: - logits which are normalized with softmax on output"""

    pred = []
    ground_truth = []
    
    print("")
    print("Running Testing...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently
    # during evaluation.
    model.eval()

    # Tracking variables 
    total_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0
    predictions=[]
    true_labels=[]
    logits_values =[]
    val_accuracy_values = []
    val_loss_values = []
    
    
    total_t0 = time.time()
    # Evaluate data for one epoch
    for batch in (prediction_dataloader):
        
        # Unpack this training batch from our dataloader. 
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using 
        # the `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        
        b_img = batch[0].to(device)

        b_input_id_cam = batch[1].to(device)
        b_input_mask_cam = batch[2].to(device)
        b_input_id_flau = batch[3].to(device)
        b_input_mask_flau = batch[4].to(device)

        b_labels = batch[5].to(device)
        
        
        # Tell pytorch not to bother with constructing the compute graph during
        # the forward pass, since this is only needed for backprop (training).
        with torch.no_grad():       
        

            # Forward pass, calculate logit predictions.
            # token_type_ids is the same as the "segment ids", which 
            # differentiates sentence 1 and 2 in 2-sentence tasks.
            # The documentation for this `model` function is here: 
            # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
            # Get the "logits" output by the model. The "logits" are the output
            # values prior to applying an activation function like the softmax.


            logits = model(b_img,b_input_id_cam ,b_input_mask_cam,b_input_id_flau,b_input_mask_flau)
            
        #new
        
        #defining the val loss
        loss = loss_criterion(logits, b_labels)
        
        # Accumulate the validation loss.
        total_eval_loss += loss.item()

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()

        # Move logits and labels to CPU
        predicted_labels=np.argmax(logits,axis=1)
        predictions.extend(predicted_labels)
        label_ids = b_labels.to('cpu').numpy()

        true_labels.extend(label_ids)

        ##########################################################################

        logits_values.append(predicted_labels)

        ##########################################################################

        # Calculate the accuracy for this batch of test sentences, and
        # accumulate it over all batches.
        total_eval_accuracy += flat_accuracy(logits, label_ids)
        
    # Report the final accuracy for this validation run.
    avg_val_accuracy = total_eval_accuracy / len(prediction_dataloader)
    val_accuracy_values.append(avg_val_accuracy)
#--------------------------------
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))

    # Calculate the average loss over all of the batches.
    avg_val_loss = total_eval_loss / len(prediction_dataloader)
#-----------------------------
    val_loss_values.append(avg_val_loss)

    
    
    # Measure how long the validation run took.
    validation_time = format_time(time.time() - t0)
    
    print("  Test Loss: {0:.2f}".format(avg_val_loss))
    print("  Test took: {:}".format(validation_time))
    print("Test F1-Score: {}".format(f1_score(true_labels,predictions,average='macro')))
    curr_f1 = f1_score(true_labels,predictions,average='macro')

    # pred.append(predictions)
    # ground_truth.append(true_labels) 

    print("")
    print("Test complete!")

    # Results = pd.DataFrame(
    # {'Pred':    predictions,
    #  'Ground': true_labels
    # })

    # #print("Total testing took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
    # print()
    # plt.plot(np.array(val_accuracy_values), 'r', label='Test accuracy')
    # plt.legend()
    # plt.title('Test Curve')
    # plt.show()

    
    # print(Results)

    # Results.to_csv( "Baseline_80_20")

    print()
    print('DONE')

    return predictions, true_labels #, softmax_logits

# %%
predictions_val, true_label = predict_pyt(model, test_dataloader)
# Out:
# Running Testing...
#   Accuracy: 0.92
#   Test Loss: 0.55
#   Test took: 0:05:17
# Test F1-Score: 0.9033605114549308
#
# Test complete!
#
# DONE

# %%
print (predictions_val,true_label )
# Out:
# [22, 12, 24, 5, 2, 14, 14, 20, 11, 24, 8, 2, 17, 20, 3, 17, 5, 3, 19, 14, 17, 11, 24, 20, 11, 4, 14, 20, 14, 20, 14, 6, 12, 3, 8, 14, 3, 9, 4, 12, 20, 20, 24, 6, 20, 14, 25, 12, 5, 7, 14, 14, 2, 22, 4, 20, 6, 3, 12, 1, 12, 12, 6, 12, 7, 14, 21, 20, 11, 5, 3, 4, 26, 6, 18, 21, 4, 5, 17, 6, 12, 3, 3, 14, 22, 23, 7, 14, 9, 20, 7, 12, 26, 12, 21, 10, 3, 14, 12, 9, 12, 7, 19, 3, 14, 17, 9, 17, 20, 24, 12, 9, 19, 5, 3, 22, 14, 19, 12, 5, 8, 8, 14, 12, 12, 4, 12, 16, 12, 14, 9, 7, 3, 2, 7, 14, 2, 14, 12, 21, 12, 5, 3, 6, 20, 4, 9, 24, 14, 11, 17, 26, 12, 23, 9, 5, 12, 2, 10, 7, 7, 9, 11, 3, 25, 22, 3, 6, 12, 12, 21, 8, 2, 9, 4, 21, 12, 7, 14, 10, 9, 12, 12, 9, 12, 6, 5, 7, 5, 12, 3, 3, 5, 9, 12, 12, 24, 12, 17, 3, 12, 17, 26, 9, 14, 18, 8, 3, 5, 9, 14, 12, 11, 4, 12, 14, 14, 12, 3, 2, 5, 20, 9, 12, 8, 9, 7, 11, 7, 17, 4, 12, 7, 24, 17, 14, 14, 8, 5, 2, 9, 9, 17, 8, 5, 21, 14, 9, 14, 7, 9, 17, 5, 12, 3, 9, 12, 6, 14, 24, 9, 21, 14, 17, 25, 2, 7, 2, 12, 11, 12, 1, 7, 6, 17, 18, 9, 8, 18, 12, 12, 21, 6, 25, 12, 17, 12, 3, 4, 22, 14, 21, 23, 6, 21, 7, 7, 0, 12, 17, 5, 20, 14, 5, 26, 8, 22, 6, 9, 19, 7, 9, 3, 21, 7, 8, 5, 7, 26, 9, 21, 12, 9, 7, 9, 17, 14, 21, 7, 17, 23, 14, 7, 21, 20, 9, 24, 7, 12, 12, 3, 17, 14, 25, 17, 17, 17, 12, 17, 19, 7, 20, 7, 4, 7, 24, 6, 24, 5, 17, 9, 9, 9, 6, 7, 21, 4, 12, 6, 3, 2, 9, 14, 17, 3, 24, 12, 20, 9, 14, 8, 12, 23, 20, 7, 6, 20, 17, 9, 14, 12, 26, 6, 20, 24, 12, 7, 9, 3, 4, 12, 12, 25, 12, 12, 3, 5, 3, 5, 12, 11, 14, 12, 18, 8, 17, 4, 14, 7, 8, 12, 18, 17, 5, 9, 17, 7, 12, 12, 3, 3, 9, 12, 5, 3, 0, 26, 20, 14, 8, 6, 6, 7, 3, 6, 9, 23, 12, 6, 17, 6, 14, 17, 3, 21, 12, 9, 20, 14, 17, 6, 3, 12, 3, 24, 26, 12, 7, 23, 24, 4, 17, 12, 25, 6, 3, 12, 24, 6, 20, 12, 17, 9, 23, 11, 14, 21, 3, 24, 9, 8, 12, 12, 9, 12, 12, 4, 12, 9, 9, 7, 24, 3, 4, 8, 17, 9, 11, 8, 12, 3, 12, 1, 7, 3, 18, 7, 17, 22, 5, 12, 17, 12, 17, 24, 18, 22, 6, 21, 12, 5, 7, 20, 23, 20, 9, 9, 2, 7, 12, 14, 12, 12, 8, 12, 12, 6, 12, 26, 12, 6, 17, 19, 9, 12, 9, 7, 12, 6, 14, 6, 21, 7, 12, 24, 12, 7, 12, 21, 6, 7, 3, 24, 24, 17, 2, 17, 17, 12, 6, 5, 12, 8, 25, 7, 7, 6, 14, 17, 9, 7, 7, 7, 12, 12, 14, 7, 11, 8, 12, 17, 8, 5, 18, 5, 17, 9, 24, 4, 5, 7, 17, 2, 20, 23, 18, 19, 23, 20, 9, 23, 4, 12, 11, 14, 4, 12, 7, 3, 13, 12, 12, 12, 5, 12, 4, 7, 25, 9, 12, 17, 20, 5, 12, 3, 14, 24, 12, 2, 7, 9, 17, 3, 8, 18, 9, 5, 12, 3, 12, 6, 9, 17, 12, 12, 12, 3, 26, 12, 5, 4, 5, 3, 23, 12, 25, 5, 21, 12, 17, 12, 9, 3, 7, 12, 3, 9, 7, 17, 18, 12, 12, 23, 17, 12, 3, 17, 3, 2, 17, 7, 24, 14, 21, 2, 14, 5, 19, 12, 12, 12, 20, 7, 5, 7, 12, 7, 12, 12, 19, 14, 14, 5, 21, 0, 24, 9, 20, 17, 8, 12, 13, 21, 0, 17, 17, 6, 8, 22, 5, 7, 14, 17, 20, 3, 7, 9, 9, 25, 7, 12, 17, 12, 6, 12, 5, 17, 9, 9, 1, 3, 19, 12, 5, 12, 14, 2, 25, 17, 7, 5, 7, 17, 14, 12, 24, 12, 8, 6, 20, 12, 7, 19, 17, 5, 13, 22, 17, 12, 20, 12, 8, 3, 4, 19, 20, 4, 18, 14, 9, 3, 8, 17, 22, 3, 14, 12, 21, 5, 13, 20, 17, 3, 22, 14, 21, 7, 6, 5, 6, 21, 21, 17, 3, 4, 3, 9, 8, 14, 8, 17, 7, 3, 5, 17, 14, 20, 7, 19, 9, 21, 7, 9, 24, 5, 7, 9, 16, 5, 5, 8, 9, 12, 17, 2, 22, 14, 12, 12, 11, 12, 5, 12, 11, 5, 6, 5, 25, 5, 12, 22, 7, 11, 12, 3, 3, 12, 17, 3, 12, 9, 2, 3, 24, 20, 17, 23, 7, 3, 8, 1, 7, 20, 6, 7, 24, 6, 2, 20, 14, 6, 12, 12, 9, 7, 9, 10, 5, 12, 12, 7, 9, 6, 9, 14, 5, 16, 24, 6, 24, 18, 12, 5, 12, 2, 17, 4, 21, 20, 14, 19, 21, 9, 12, 16, 4, 17, 7, 7, 14, 3, 14, 9, 12, 17, 14, 7, 25, 3, 12, 20, 7, 7, 12, 3, 12, 12, 9, 5, 3, 9, 9, 5, 11, 3, 12, 12, 18, 24, 12, 7, 12, 19, 3, 7, 11, 12, 17, 14, 7, 12, 16, 9, 8, 9, 12, 14, 12, 24, 24, 12, 12, 7, 9, 7, 3, 24, 25, 3, 5, 19, 1, 17, 0, 26, 6, 17, 24, 26, 5, 20, 3, 7, 5, 11, 6, 20, 12, 2, 6, 24, 23, 9, 4, 7, 21, 25, 4, 24, 24, 14, 4, 12, 22, 21, 2, 9, 14, 6, 7, 9, 6, 4, 14, 14, 6, 18, 5, 9, 21, 7, 9, 4, 7, 12, 12, 21, 24, 6, 7, 19, 14, 25, 3, 12, 12, 17, 12, 11, 5, 14, 3, 26, 19, 20, 17, 3, 5, 22, 12, 20, 12, 3, 5, 9, 8, 14, 9, 12, 11, 12, 6, 6, 5, 24, 20, 24, 12, 9, 12, 5, 3, 14, 21, 12, 3, 12, 12, 14, 5, 7, 17, 24, 7, 17, 12, 7, 25, 12, 12, 5, 6, 12, 5, 4, 20, ...

# %%
 Results = pd.DataFrame(
    {'Pred':    predictions_val,
     'Ground': true_label
    })

# %%
Results.to_csv( "Baseline_80_20_concat")

# %%
Results = pd.read_csv('Baseline_80_20_concat')

# %% [markdown]
# #1- Acuraccy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Results['Ground'], Results['Pred'])
# Out:
# 0.9221698113207547

# %% [markdown]
# #2- F1 - Score

# %%
print(f1_score(Results['Ground'],Results['Pred'],average='macro'))
# Out:
# 0.9033605114549308

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
confusion_mat = confusion_matrix(Results['Ground'], Results['Pred'])


print (accuracy_score(Results['Ground'],Results['Pred']))
# Out:
# 0.9221698113207547

# %% [markdown]
# #3- Report

# %%
from sklearn.metrics import classification_report

target_names = ['class 1', 'class 2', 'class 3', 'class 4', 'class 5', 'class 6',
                'class 7', 'class 8', 'class 9', 'class 10', 'class 11', 'class 12', 
                'class 13', 'class 14', 'class 15', 'class 16', 'class 17', 'class 18',
                'class 19','class 20', 'class 21', 'class 22', 'class 23', 'class 24', 'class 25', 'class 26', 'class 27']

print(classification_report(Results['Ground'], Results['Pred'], target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 1       0.88      0.84      0.86        68
#      class 2       0.97      0.94      0.95        64
#      class 3       0.92      0.95      0.93       241
#      class 4       0.85      0.82      0.83       760
#      class 5       0.98      0.99      0.99       347
#      class 6       0.96      0.94      0.95       760
#      class 7       0.88      0.86      0.87       505
#      class 8       0.89      0.90      0.89       979
#      class 9       0.77      0.78      0.77       316
#     class 10       0.94      0.94      0.94       819
#     class 11       0.88      0.92      0.90        25
#     class 12       0.89      0.87      0.88       189
#     class 13       0.98      0.99      0.99      1861
#     class 14       0.66      0.68      0.67        31
#     class 15       0.99      1.00      0.99       774
#     class 16       0.88      0.64      0.74        11
#     class 17       0.99      0.96      0.97        70
#     class 18       0.88      0.87      0.88       942
#     class 19       0.91      0.90      0.90       173
#     class 20       0.96      0.98      0.97       140
#     class 21       0.84      0.86      0.85       428
#     class 22       0.86      0.90      0.88       443
#     class 23       0.91      0.92      0.92       152
#     class 24       0.98      1.00      0.99       174
#     class 25       0.96      0.93      0.95       460
#     class 26       0.93      0.95      0.94       152
#     class 27       0.99      0.97      0.98       140
#
#     accuracy                           0.92     11024
#    macro avg       0.91      0.90      0.90     11024
# weighted avg       0.92      0.92      0.92     11024

# %% [markdown]
# # 4- Confusion Matrix

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(confusion_mat, index = [i for i in range(27)],
                                    columns = [i for i in range(27)])
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(confusion_mat, index = [i for i in range(27)],
                                    columns = [i for i in range(27)])
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True)

# %%
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

values = np.array(true_label)
print(values)
# integer encode
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(values)
print(integer_encoded)

onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
true_label_onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
# Out:
# [22 12 24 ... 17  7 12]
# [22 12 24 ... 17  7 12]

# %%
values = np.array(predictions_val)
print(values)
# integer encode
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(values)
print(integer_encoded)

onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
predictions_val_onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
# Out:
# [22 12 24 ... 17  7 12]
# [22 12 24 ... 17  7 12]

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier



n_classes = 27

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(true_label_onehot_encoded[:, i], predictions_val_onehot_encoded[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(true_label_onehot_encoded.ravel(), predictions_val_onehot_encoded.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# # Plot of a ROC curve for a specific class
# plt.figure()
# plt.plot(fpr[2], tpr[2], label='ROC curve (area = %0.2f)' % roc_auc[2])
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# Plot ROC curve
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]))
# for i in range(n_classes):
#     plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
#                                    ''.format(i, roc_auc[i]))

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i])

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
# Out:
# Automatically created module for IPython interactive environment
